# %%
pip install keras-tuner
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: keras-tuner in /environment/miniconda3/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: ipython in /environment/miniconda3/lib/python3.8/site-packages (from keras-tuner) (8.11.0)
# Requirement already satisfied: tensorflow>=2.0 in /environment/miniconda3/lib/python3.8/site-packages (from keras-tuner) (2.11.0)
# Requirement already satisfied: packaging in /environment/miniconda3/lib/python3.8/site-packages (from keras-tuner) (23.0)
# Requirement already satisfied: requests in /environment/miniconda3/lib/python3.8/site-packages (from keras-tuner) (2.24.0)
# Requirement already satisfied: kt-legacy in /environment/miniconda3/lib/python3.8/site-packages (from keras-tuner) (1.0.4)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (0.31.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (1.4.0)
# Requirement already satisfied: setuptools in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (65.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (1.51.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (1.6.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (3.19.6)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (2.11.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (4.5.0)
# Requirement already satisfied: numpy>=1.20 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (1.24.1)
# Requirement already satisfied: termcolor>=1.1.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (2.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (23.3.3)
# Requirement already satisfied: six>=1.12.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (1.16.0)
# Requirement already satisfied: h5py>=2.9.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorflow>=2.0->keras-tuner) (15.0.6.1)
# Requirement already satisfied: decorator in /environment/miniconda3/lib/python3.8/site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /environment/miniconda3/lib/python3.8/site-packages (from ipython->keras-tuner) (0.18.2)
# Requirement already satisfied: pygments>=2.4.0 in /environment/miniconda3/lib/python3.8/site-packages (from ipython->keras-tuner) (2.14.0)
# Requirement already satisfied: pickleshare in /environment/miniconda3/lib/python3.8/site-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /environment/miniconda3/lib/python3.8/site-packages (from ipython->keras-tuner) (0.1.6)
# Requirement already satisfied: traitlets>=5 in /environment/miniconda3/lib/python3.8/site-packages (from ipython->keras-tuner) (5.9.0)
# Requirement already satisfied: stack-data in /environment/miniconda3/lib/python3.8/site-packages (from ipython->keras-tuner) (0.6.2)
# Requirement already satisfied: backcall in /environment/miniconda3/lib/python3.8/site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /environment/miniconda3/lib/python3.8/site-packages (from ipython->keras-tuner) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /environment/miniconda3/lib/python3.8/site-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /environment/miniconda3/lib/python3.8/site-packages (from requests->keras-tuner) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /environment/miniconda3/lib/python3.8/site-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /environment/miniconda3/lib/python3.8/site-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /environment/miniconda3/lib/python3.8/site-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /environment/miniconda3/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow>=2.0->keras-tuner) (0.36.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /environment/miniconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /environment/miniconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: wcwidth in /environment/miniconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /environment/miniconda3/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /environment/miniconda3/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /environment/miniconda3/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /environment/miniconda3/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (2.16.2)
# Requirement already satisfied: markdown>=2.6.8 in /environment/miniconda3/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.4.1)
# Requirement already satisfied: asttokens>=2.1.0 in /environment/miniconda3/lib/python3.8/site-packages (from stack-data->ipython->keras-tuner) (2.2.1)
# Requirement already satisfied: pure-eval in /environment/miniconda3/lib/python3.8/site-packages (from stack-data->ipython->keras-tuner) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /environment/miniconda3/lib/python3.8/site-packages (from stack-data->ipython->keras-tuner) (1.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /environment/miniconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /environment/miniconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /environment/miniconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /environment/miniconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /environment/miniconda3/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /environment/miniconda3/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /environment/miniconda3/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /environment/miniconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /environment/miniconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python-headless
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: opencv-python-headless in /environment/miniconda3/lib/python3.8/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in /environment/miniconda3/lib/python3.8/site-packages (from opencv-python-headless) (1.24.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: scikit-learn in /environment/miniconda3/lib/python3.8/site-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /environment/miniconda3/lib/python3.8/site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: numpy>=1.17.3 in /environment/miniconda3/lib/python3.8/site-packages (from scikit-learn) (1.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /environment/miniconda3/lib/python3.8/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /environment/miniconda3/lib/python3.8/site-packages (from scikit-learn) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imgaug
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: imgaug in /environment/miniconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: opencv-python in /environment/miniconda3/lib/python3.8/site-packages (from imgaug) (4.7.0.72)
# Requirement already satisfied: six in /environment/miniconda3/lib/python3.8/site-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /environment/miniconda3/lib/python3.8/site-packages (from imgaug) (1.24.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /environment/miniconda3/lib/python3.8/site-packages (from imgaug) (0.20.0)
# Requirement already satisfied: imageio in /environment/miniconda3/lib/python3.8/site-packages (from imgaug) (2.26.0)
# Requirement already satisfied: matplotlib in /environment/miniconda3/lib/python3.8/site-packages (from imgaug) (3.7.1)
# Requirement already satisfied: Shapely in /environment/miniconda3/lib/python3.8/site-packages (from imgaug) (2.0.1)
# Requirement already satisfied: Pillow in /environment/miniconda3/lib/python3.8/site-packages (from imgaug) (9.3.0)
# Requirement already satisfied: scipy in /environment/miniconda3/lib/python3.8/site-packages (from imgaug) (1.9.1)
# Requirement already satisfied: networkx>=2.8 in /environment/miniconda3/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug) (3.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /environment/miniconda3/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.1 in /environment/miniconda3/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug) (0.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /environment/miniconda3/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug) (2023.3.15)
# Requirement already satisfied: packaging>=20.0 in /environment/miniconda3/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /environment/miniconda3/lib/python3.8/site-packages (from matplotlib->imgaug) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /environment/miniconda3/lib/python3.8/site-packages (from matplotlib->imgaug) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /environment/miniconda3/lib/python3.8/site-packages (from matplotlib->imgaug) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /environment/miniconda3/lib/python3.8/site-packages (from matplotlib->imgaug) (4.39.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /environment/miniconda3/lib/python3.8/site-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /environment/miniconda3/lib/python3.8/site-packages (from matplotlib->imgaug) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /environment/miniconda3/lib/python3.8/site-packages (from matplotlib->imgaug) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /environment/miniconda3/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->imgaug) (3.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import cv2
import imgaug.augmenters as iaa
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, concatenate
from sklearn.model_selection import train_test_split
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.utils import Sequence
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_percentage_error

class AugmentedDataGenerator(Sequence):
    def __init__(self, X, y, batch_size=32, augmentations=None):
        self.X = X
        self.y = y
        self.batch_size = batch_size
        self.augmentations = augmentations

    def __len__(self):
        return int(np.ceil(len(self.X) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.X[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]

        if self.augmentations:
            batch_x = augment_images(batch_x)

        return batch_x, batch_y

# Define the augmentations using imgaug
augmentation = iaa.Sequential([
    iaa.Fliplr(0.5), # horizontally flip 50% of the images
    iaa.Rotate((-10, 10)), # rotate images between -10 and 10 degrees
])

# Apply augmentations to the images
def augment_images(images):
    return np.array([augmentation.augment_image(image) for image in images])

# load train dataset
train_df = pd.read_csv('data/training_norm.csv')
train_images = []
for image_id in train_df['image_id']:
    image = cv2.imread(f'data/training_data/training_data/{image_id}.png')
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    train_images.append(image)
train_images = np.array(train_images)
train_angles = np.array(train_df['angle'])
train_speeds = np.array(train_df['speed'])

# Apply augmentations to the train images
train_images = augment_images(train_images)

# load test dataset
test_images = []
for i in range(1, 1021):
    image = cv2.imread(f'data/test_data/test_data/{i}.png')
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    test_images.append(image)
test_images = np.array(test_images)
test_ids = np.arange(1, 1021)


# split the data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(train_images, train_df[['angle', 'speed']].values, test_size=0.2, random_state=42)

# Apply augmentations to the train set
# X_train = augment_images(X_train)

# define the early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1)
# Out:
# 2023-03-31 00:52:01.883341: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-31 00:52:02.977814: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /environment/miniconda3/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-03-31 00:52:02.977908: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /environment/miniconda3/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-03-31 00:52:02.977914: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# define the model
def build_model(hp):
    # input layer
    input_layer = Input(shape=(240, 320, 3))

    # convolutional layers
    num_conv_layers = hp.Int('num_conv_layers', min_value=2, max_value=5, step=1)
    conv_layer_filters = [hp.Choice(f'conv_layer_{i}_filters', values=[32, 64, 128, 256], ordered=False, default=64) for i in range(num_conv_layers)]
    conv_layer_kernel_sizes = [hp.Choice(f'conv_layer_{i}_kernel_sizes', values=[3, 5, 7], ordered=False, default=3) for i in range(num_conv_layers)]
    conv_layer_activations = [hp.Choice(f'conv_layer_{i}_activations', values=['relu', 'elu'], default='relu') for i in range(num_conv_layers)]
    x = input_layer
    for i in range(num_conv_layers):
        x = Conv2D(filters=conv_layer_filters[i], kernel_size=conv_layer_kernel_sizes[i], activation=conv_layer_activations[i], padding='same')(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)

    # fully connected layers
    x = Flatten()(x)
    num_dense_layers = hp.Int('num_dense_layers', min_value=1, max_value=3, step=1)
    for i in range(num_dense_layers):
        dense_layer_units = hp.Int(f'dense_layer_{i}_units', min_value=32, max_value=512, step=32)
        dense_layer_activation = hp.Choice(f'dense_layer_{i}_activation', values=['relu', 'elu'], default='relu')
        x = Dense(units=dense_layer_units, activation=dense_layer_activation)(x)
        dropout_rate = hp.Float(f'dropout_{i}', min_value=0.0, max_value=0.5, step=0.1, default=0.25)
        x = Dropout(rate=dropout_rate)(x)

    # output layer
    angle_output = Dense(units=1, name='angle_output')(x)
    speed_output = Dense(units=1, name='speed_output')(x)
    model = Model(inputs=input_layer, outputs=[angle_output, speed_output])

    # compile the model
    optimizer = Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log'))
    loss = {'angle_output': 'mean_squared_error', 'speed_output': 'mean_squared_error'}
    metrics = {'angle_output': 'mae', 'speed_output': 'mae'}
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    return model

# define the tuner
tuner = RandomSearch(
build_model,
objective='val_loss',
max_trials=10,
directory='output',
project_name='steering_angle_regression'
)


# search for the best hyperparameters
tuner.search(X_train, y_train, epochs=50, validation_data=(X_val, y_val), callbacks=[early_stop])

# get the best model
best_model = tuner.get_best_models(num_models=1)[0]
# save the best model as an .h5 file
best_model.save('best_model.h5')
# Out:
# INFO:tensorflow:Reloading Tuner from output/steering_angle_regression/tuner0.json
# INFO:tensorflow:Oracle triggered exit
# 2023-03-31 00:52:45.369011: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 00:52:45.441964: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 00:52:45.442150: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 00:52:45.443586: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-31 00:52:45.446393: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 00:52:45.446594: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 00:52:45.446753: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 00:52:46.501275: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 00:52:46.502188: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 00:52:46.502450: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 00:52:46.503320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22112 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:10:00.0, compute capability: 8.9

# %%
# Create the data generator for the training set
train_generator = AugmentedDataGenerator(X_train, y_train, batch_size=32, augmentations=augmentation)

# Train the model using the generator
history = best_model.fit(train_generator, epochs=100, validation_data=(X_val, y_val), callbacks=[early_stop])
y_val_pred = best_model.predict(X_val)
angle_r2 = r2_score(y_val[:, 0], y_val_pred[0].flatten())
angle_rmse = np.sqrt(mean_squared_error(y_val[:, 0], y_val_pred[0].flatten()))
angle_mape = mean_absolute_percentage_error(y_val[:, 0], y_val_pred[0].flatten())
speed_r2 = r2_score(y_val[:, 1], y_val_pred[1].flatten())
speed_rmse = np.sqrt(mean_squared_error(y_val[:, 1], y_val_pred[1].flatten()))
speed_mape = mean_absolute_percentage_error(y_val[:, 1], y_val_pred[1].flatten())

print("Angle R-squared:", angle_r2)
print("Angle RMSE:", angle_rmse)
print("Angle MAPE:", angle_mape)
print("Speed R-squared:", speed_r2)
print("Speed RMSE:", speed_rmse)
print("Speed MAPE:", speed_mape)
# train the model on the entire training dataset
history = best_model.fit(train_images, [train_angles, train_speeds], epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 2023-03-31 00:52:49.814402: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8101
# 2023-03-31 00:52:51.659506: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-03-31 00:52:51.675314: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2023-03-31 00:52:51.675343: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at /usr/local/cuda-11.2/bin/ptxas
# 2023-03-31 00:52:51.675401: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:318] UNIMPLEMENTED: /usr/local/cuda-11.2/bin/ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-03-31 00:52:53.185097: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-03-31 00:52:53.254740: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f5b85455550 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-03-31 00:52:53.254781: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2023-03-31 00:52:53.338719: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-03-31 00:52:53.748846: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-03-31 00:52:53.752829: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 345/345 [==============================] - 24s 44ms/step - loss: 0.1436 - angle_output_loss: 0.0716 - speed_output_loss: 0.0720 - angle_output_mae: 0.2332 - speed_output_mae: 0.2335 - val_loss: 0.1392 - val_angle_output_loss: 0.0696 - val_speed_output_loss: 0.0696 - val_angle_output_mae: 0.2318 - val_speed_output_mae: 0.2318
# Epoch 2/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.1415 - angle_output_loss: 0.0706 - speed_output_loss: 0.0709 - angle_output_mae: 0.2320 - speed_output_mae: 0.2320 - val_loss: 0.1362 - val_angle_output_loss: 0.0680 - val_speed_output_loss: 0.0682 - val_angle_output_mae: 0.2307 - val_speed_output_mae: 0.2307
# Epoch 3/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.1389 - angle_output_loss: 0.0693 - speed_output_loss: 0.0695 - angle_output_mae: 0.2311 - speed_output_mae: 0.2311 - val_loss: 0.1365 - val_angle_output_loss: 0.0682 - val_speed_output_loss: 0.0683 - val_angle_output_mae: 0.2311 - val_speed_output_mae: 0.2313
# Epoch 4/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.1392 - angle_output_loss: 0.0695 - speed_output_loss: 0.0697 - angle_output_mae: 0.2312 - speed_output_mae: 0.2313 - val_loss: 0.1373 - val_angle_output_loss: 0.0686 - val_speed_output_loss: 0.0686 - val_angle_output_mae: 0.2309 - val_speed_output_mae: 0.2308
# Epoch 5/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.1385 - angle_output_loss: 0.0692 - speed_output_loss: 0.0694 - angle_output_mae: 0.2310 - speed_output_mae: 0.2311 - val_loss: 0.1367 - val_angle_output_loss: 0.0684 - val_speed_output_loss: 0.0683 - val_angle_output_mae: 0.2317 - val_speed_output_mae: 0.2318
# Epoch 6/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.1370 - angle_output_loss: 0.0684 - speed_output_loss: 0.0686 - angle_output_mae: 0.2303 - speed_output_mae: 0.2304 - val_loss: 0.1340 - val_angle_output_loss: 0.0670 - val_speed_output_loss: 0.0670 - val_angle_output_mae: 0.2294 - val_speed_output_mae: 0.2293
# Epoch 7/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.1359 - angle_output_loss: 0.0678 - speed_output_loss: 0.0681 - angle_output_mae: 0.2295 - speed_output_mae: 0.2297 - val_loss: 0.1390 - val_angle_output_loss: 0.0693 - val_speed_output_loss: 0.0697 - val_angle_output_mae: 0.2309 - val_speed_output_mae: 0.2308
# Epoch 8/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.1380 - angle_output_loss: 0.0688 - speed_output_loss: 0.0691 - angle_output_mae: 0.2305 - speed_output_mae: 0.2307 - val_loss: 0.1374 - val_angle_output_loss: 0.0687 - val_speed_output_loss: 0.0688 - val_angle_output_mae: 0.2308 - val_speed_output_mae: 0.2308
# Epoch 9/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.1365 - angle_output_loss: 0.0681 - speed_output_loss: 0.0683 - angle_output_mae: 0.2298 - speed_output_mae: 0.2299 - val_loss: 0.1372 - val_angle_output_loss: 0.0686 - val_speed_output_loss: 0.0686 - val_angle_output_mae: 0.2305 - val_speed_output_mae: 0.2306
# Epoch 10/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.1371 - angle_output_loss: 0.0685 - speed_output_loss: 0.0687 - angle_output_mae: 0.2301 - speed_output_mae: 0.2302 - val_loss: 0.1416 - val_angle_output_loss: 0.0707 - val_speed_output_loss: 0.0709 - val_angle_output_mae: 0.2350 - val_speed_output_mae: 0.2351
# Epoch 11/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.1356 - angle_output_loss: 0.0676 - speed_output_loss: 0.0679 - angle_output_mae: 0.2294 - speed_output_mae: 0.2296 - val_loss: 0.1361 - val_angle_output_loss: 0.0679 - val_speed_output_loss: 0.0681 - val_angle_output_mae: 0.2304 - val_speed_output_mae: 0.2306
# Epoch 11: early stopping
# 87/87 [==============================] - 1s 12ms/step
# Angle R-squared: -1.3663656627659009
# Angle RMSE: 0.2421656656942458
# Angle MAPE: 8895229670604.184
# Speed R-squared: 0.5955350245234181
# Speed RMSE: 0.27621228669193143
# Speed MAPE: 397352923440271.0
# Epoch 1/100
# 345/345 [==============================] - 15s 43ms/step - loss: 0.0614 - angle_output_loss: 0.0211 - speed_output_loss: 0.0403 - angle_output_mae: 0.1094 - speed_output_mae: 0.1293 - val_loss: 0.0416 - val_angle_output_loss: 0.0140 - val_speed_output_loss: 0.0275 - val_angle_output_mae: 0.0888 - val_speed_output_mae: 0.0963
# Epoch 2/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0451 - angle_output_loss: 0.0156 - speed_output_loss: 0.0295 - angle_output_mae: 0.0930 - speed_output_mae: 0.1088 - val_loss: 0.0460 - val_angle_output_loss: 0.0139 - val_speed_output_loss: 0.0321 - val_angle_output_mae: 0.0888 - val_speed_output_mae: 0.1008
# Epoch 3/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0423 - angle_output_loss: 0.0145 - speed_output_loss: 0.0278 - angle_output_mae: 0.0895 - speed_output_mae: 0.1059 - val_loss: 0.0399 - val_angle_output_loss: 0.0128 - val_speed_output_loss: 0.0271 - val_angle_output_mae: 0.0851 - val_speed_output_mae: 0.0784
# Epoch 4/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0389 - angle_output_loss: 0.0137 - speed_output_loss: 0.0251 - angle_output_mae: 0.0867 - speed_output_mae: 0.1024 - val_loss: 0.0362 - val_angle_output_loss: 0.0108 - val_speed_output_loss: 0.0254 - val_angle_output_mae: 0.0761 - val_speed_output_mae: 0.0836
# Epoch 5/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0358 - angle_output_loss: 0.0131 - speed_output_loss: 0.0227 - angle_output_mae: 0.0846 - speed_output_mae: 0.0978 - val_loss: 0.0356 - val_angle_output_loss: 0.0103 - val_speed_output_loss: 0.0253 - val_angle_output_mae: 0.0750 - val_speed_output_mae: 0.0781
# Epoch 6/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0339 - angle_output_loss: 0.0130 - speed_output_loss: 0.0209 - angle_output_mae: 0.0843 - speed_output_mae: 0.0941 - val_loss: 0.0371 - val_angle_output_loss: 0.0102 - val_speed_output_loss: 0.0269 - val_angle_output_mae: 0.0751 - val_speed_output_mae: 0.0702
# Epoch 7/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0319 - angle_output_loss: 0.0122 - speed_output_loss: 0.0197 - angle_output_mae: 0.0812 - speed_output_mae: 0.0918 - val_loss: 0.0364 - val_angle_output_loss: 0.0105 - val_speed_output_loss: 0.0259 - val_angle_output_mae: 0.0746 - val_speed_output_mae: 0.0820
# Epoch 8/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0315 - angle_output_loss: 0.0120 - speed_output_loss: 0.0196 - angle_output_mae: 0.0802 - speed_output_mae: 0.0917 - val_loss: 0.0402 - val_angle_output_loss: 0.0115 - val_speed_output_loss: 0.0287 - val_angle_output_mae: 0.0782 - val_speed_output_mae: 0.0809
# Epoch 9/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0305 - angle_output_loss: 0.0116 - speed_output_loss: 0.0189 - angle_output_mae: 0.0798 - speed_output_mae: 0.0899 - val_loss: 0.0353 - val_angle_output_loss: 0.0113 - val_speed_output_loss: 0.0240 - val_angle_output_mae: 0.0785 - val_speed_output_mae: 0.0807
# Epoch 10/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0293 - angle_output_loss: 0.0112 - speed_output_loss: 0.0181 - angle_output_mae: 0.0783 - speed_output_mae: 0.0882 - val_loss: 0.0370 - val_angle_output_loss: 0.0106 - val_speed_output_loss: 0.0264 - val_angle_output_mae: 0.0749 - val_speed_output_mae: 0.0830
# Epoch 11/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0272 - angle_output_loss: 0.0110 - speed_output_loss: 0.0161 - angle_output_mae: 0.0772 - speed_output_mae: 0.0843 - val_loss: 0.0341 - val_angle_output_loss: 0.0102 - val_speed_output_loss: 0.0239 - val_angle_output_mae: 0.0725 - val_speed_output_mae: 0.0655
# Epoch 12/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0262 - angle_output_loss: 0.0103 - speed_output_loss: 0.0159 - angle_output_mae: 0.0748 - speed_output_mae: 0.0836 - val_loss: 0.0343 - val_angle_output_loss: 0.0099 - val_speed_output_loss: 0.0244 - val_angle_output_mae: 0.0716 - val_speed_output_mae: 0.0764
# Epoch 13/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0258 - angle_output_loss: 0.0101 - speed_output_loss: 0.0157 - angle_output_mae: 0.0741 - speed_output_mae: 0.0831 - val_loss: 0.0350 - val_angle_output_loss: 0.0101 - val_speed_output_loss: 0.0248 - val_angle_output_mae: 0.0734 - val_speed_output_mae: 0.0700
# Epoch 14/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0236 - angle_output_loss: 0.0100 - speed_output_loss: 0.0137 - angle_output_mae: 0.0741 - speed_output_mae: 0.0792 - val_loss: 0.0357 - val_angle_output_loss: 0.0104 - val_speed_output_loss: 0.0253 - val_angle_output_mae: 0.0750 - val_speed_output_mae: 0.0756
# Epoch 15/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0223 - angle_output_loss: 0.0096 - speed_output_loss: 0.0127 - angle_output_mae: 0.0723 - speed_output_mae: 0.0763 - val_loss: 0.0343 - val_angle_output_loss: 0.0094 - val_speed_output_loss: 0.0249 - val_angle_output_mae: 0.0705 - val_speed_output_mae: 0.0911
# Epoch 16/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0205 - angle_output_loss: 0.0091 - speed_output_loss: 0.0113 - angle_output_mae: 0.0712 - speed_output_mae: 0.0734 - val_loss: 0.0342 - val_angle_output_loss: 0.0093 - val_speed_output_loss: 0.0248 - val_angle_output_mae: 0.0692 - val_speed_output_mae: 0.0656
# Epoch 17/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0209 - angle_output_loss: 0.0091 - speed_output_loss: 0.0118 - angle_output_mae: 0.0706 - speed_output_mae: 0.0752 - val_loss: 0.0294 - val_angle_output_loss: 0.0094 - val_speed_output_loss: 0.0200 - val_angle_output_mae: 0.0693 - val_speed_output_mae: 0.0620
# Epoch 18/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0195 - angle_output_loss: 0.0086 - speed_output_loss: 0.0109 - angle_output_mae: 0.0694 - speed_output_mae: 0.0730 - val_loss: 0.0359 - val_angle_output_loss: 0.0097 - val_speed_output_loss: 0.0262 - val_angle_output_mae: 0.0717 - val_speed_output_mae: 0.0714
# Epoch 19/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0195 - angle_output_loss: 0.0086 - speed_output_loss: 0.0109 - angle_output_mae: 0.0688 - speed_output_mae: 0.0715 - val_loss: 0.0330 - val_angle_output_loss: 0.0104 - val_speed_output_loss: 0.0226 - val_angle_output_mae: 0.0720 - val_speed_output_mae: 0.0642
# Epoch 20/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0179 - angle_output_loss: 0.0082 - speed_output_loss: 0.0097 - angle_output_mae: 0.0678 - speed_output_mae: 0.0693 - val_loss: 0.0300 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0208 - val_angle_output_mae: 0.0700 - val_speed_output_mae: 0.0555
# Epoch 21/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0180 - angle_output_loss: 0.0083 - speed_output_loss: 0.0097 - angle_output_mae: 0.0684 - speed_output_mae: 0.0687 - val_loss: 0.0326 - val_angle_output_loss: 0.0102 - val_speed_output_loss: 0.0225 - val_angle_output_mae: 0.0723 - val_speed_output_mae: 0.0625
# Epoch 22/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0184 - angle_output_loss: 0.0082 - speed_output_loss: 0.0102 - angle_output_mae: 0.0679 - speed_output_mae: 0.0688 - val_loss: 0.0340 - val_angle_output_loss: 0.0095 - val_speed_output_loss: 0.0245 - val_angle_output_mae: 0.0711 - val_speed_output_mae: 0.0664
# Epoch 23/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0165 - angle_output_loss: 0.0077 - speed_output_loss: 0.0088 - angle_output_mae: 0.0663 - speed_output_mae: 0.0660 - val_loss: 0.0300 - val_angle_output_loss: 0.0090 - val_speed_output_loss: 0.0209 - val_angle_output_mae: 0.0692 - val_speed_output_mae: 0.0573
# Epoch 24/100
# 345/345 [==============================] - 15s 43ms/step - loss: 0.0157 - angle_output_loss: 0.0075 - speed_output_loss: 0.0082 - angle_output_mae: 0.0654 - speed_output_mae: 0.0631 - val_loss: 0.0312 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0216 - val_angle_output_mae: 0.0699 - val_speed_output_mae: 0.0543
# Epoch 25/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0152 - angle_output_loss: 0.0072 - speed_output_loss: 0.0079 - angle_output_mae: 0.0643 - speed_output_mae: 0.0616 - val_loss: 0.0310 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0218 - val_angle_output_mae: 0.0688 - val_speed_output_mae: 0.0570
# Epoch 26/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0140 - angle_output_loss: 0.0070 - speed_output_loss: 0.0070 - angle_output_mae: 0.0630 - speed_output_mae: 0.0593 - val_loss: 0.0288 - val_angle_output_loss: 0.0091 - val_speed_output_loss: 0.0197 - val_angle_output_mae: 0.0684 - val_speed_output_mae: 0.0533
# Epoch 27/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0136 - angle_output_loss: 0.0068 - speed_output_loss: 0.0068 - angle_output_mae: 0.0624 - speed_output_mae: 0.0588 - val_loss: 0.0313 - val_angle_output_loss: 0.0088 - val_speed_output_loss: 0.0225 - val_angle_output_mae: 0.0683 - val_speed_output_mae: 0.0558
# Epoch 28/100
# 345/345 [==============================] - 15s 43ms/step - loss: 0.0123 - angle_output_loss: 0.0065 - speed_output_loss: 0.0059 - angle_output_mae: 0.0613 - speed_output_mae: 0.0545 - val_loss: 0.0295 - val_angle_output_loss: 0.0088 - val_speed_output_loss: 0.0207 - val_angle_output_mae: 0.0669 - val_speed_output_mae: 0.0498
# Epoch 29/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0122 - angle_output_loss: 0.0064 - speed_output_loss: 0.0058 - angle_output_mae: 0.0614 - speed_output_mae: 0.0539 - val_loss: 0.0286 - val_angle_output_loss: 0.0090 - val_speed_output_loss: 0.0196 - val_angle_output_mae: 0.0675 - val_speed_output_mae: 0.0484
# Epoch 30/100
# 345/345 [==============================] - 16s 47ms/step - loss: 0.0116 - angle_output_loss: 0.0063 - speed_output_loss: 0.0053 - angle_output_mae: 0.0605 - speed_output_mae: 0.0516 - val_loss: 0.0305 - val_angle_output_loss: 0.0095 - val_speed_output_loss: 0.0210 - val_angle_output_mae: 0.0703 - val_speed_output_mae: 0.0504
# Epoch 31/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0118 - angle_output_loss: 0.0064 - speed_output_loss: 0.0054 - angle_output_mae: 0.0611 - speed_output_mae: 0.0520 - val_loss: 0.0296 - val_angle_output_loss: 0.0090 - val_speed_output_loss: 0.0206 - val_angle_output_mae: 0.0685 - val_speed_output_mae: 0.0510
# Epoch 32/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0114 - angle_output_loss: 0.0062 - speed_output_loss: 0.0052 - angle_output_mae: 0.0596 - speed_output_mae: 0.0499 - val_loss: 0.0307 - val_angle_output_loss: 0.0098 - val_speed_output_loss: 0.0209 - val_angle_output_mae: 0.0713 - val_speed_output_mae: 0.0544
# Epoch 33/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0109 - angle_output_loss: 0.0061 - speed_output_loss: 0.0048 - angle_output_mae: 0.0597 - speed_output_mae: 0.0484 - val_loss: 0.0304 - val_angle_output_loss: 0.0089 - val_speed_output_loss: 0.0215 - val_angle_output_mae: 0.0677 - val_speed_output_mae: 0.0494
# Epoch 34/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0099 - angle_output_loss: 0.0057 - speed_output_loss: 0.0042 - angle_output_mae: 0.0575 - speed_output_mae: 0.0460 - val_loss: 0.0307 - val_angle_output_loss: 0.0090 - val_speed_output_loss: 0.0217 - val_angle_output_mae: 0.0681 - val_speed_output_mae: 0.0488
# Epoch 35/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0091 - angle_output_loss: 0.0054 - speed_output_loss: 0.0037 - angle_output_mae: 0.0561 - speed_output_mae: 0.0435 - val_loss: 0.0301 - val_angle_output_loss: 0.0089 - val_speed_output_loss: 0.0212 - val_angle_output_mae: 0.0681 - val_speed_output_mae: 0.0443
# Epoch 36/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0084 - angle_output_loss: 0.0052 - speed_output_loss: 0.0033 - angle_output_mae: 0.0551 - speed_output_mae: 0.0414 - val_loss: 0.0312 - val_angle_output_loss: 0.0098 - val_speed_output_loss: 0.0214 - val_angle_output_mae: 0.0721 - val_speed_output_mae: 0.0495
# Epoch 37/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0124 - angle_output_loss: 0.0064 - speed_output_loss: 0.0060 - angle_output_mae: 0.0608 - speed_output_mae: 0.0482 - val_loss: 0.0379 - val_angle_output_loss: 0.0111 - val_speed_output_loss: 0.0268 - val_angle_output_mae: 0.0775 - val_speed_output_mae: 0.0614
# Epoch 38/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0161 - angle_output_loss: 0.0074 - speed_output_loss: 0.0087 - angle_output_mae: 0.0645 - speed_output_mae: 0.0535 - val_loss: 0.0317 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0225 - val_angle_output_mae: 0.0688 - val_speed_output_mae: 0.0507
# Epoch 39/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0109 - angle_output_loss: 0.0059 - speed_output_loss: 0.0050 - angle_output_mae: 0.0591 - speed_output_mae: 0.0442 - val_loss: 0.0323 - val_angle_output_loss: 0.0089 - val_speed_output_loss: 0.0233 - val_angle_output_mae: 0.0675 - val_speed_output_mae: 0.0461
# Epoch 40/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0084 - angle_output_loss: 0.0053 - speed_output_loss: 0.0031 - angle_output_mae: 0.0560 - speed_output_mae: 0.0396 - val_loss: 0.0302 - val_angle_output_loss: 0.0089 - val_speed_output_loss: 0.0213 - val_angle_output_mae: 0.0674 - val_speed_output_mae: 0.0425
# Epoch 41/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0072 - angle_output_loss: 0.0046 - speed_output_loss: 0.0026 - angle_output_mae: 0.0523 - speed_output_mae: 0.0367 - val_loss: 0.0300 - val_angle_output_loss: 0.0084 - val_speed_output_loss: 0.0216 - val_angle_output_mae: 0.0657 - val_speed_output_mae: 0.0416
# Epoch 42/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0071 - angle_output_loss: 0.0045 - speed_output_loss: 0.0026 - angle_output_mae: 0.0519 - speed_output_mae: 0.0363 - val_loss: 0.0302 - val_angle_output_loss: 0.0087 - val_speed_output_loss: 0.0215 - val_angle_output_mae: 0.0663 - val_speed_output_mae: 0.0395
# Epoch 43/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0067 - angle_output_loss: 0.0043 - speed_output_loss: 0.0024 - angle_output_mae: 0.0505 - speed_output_mae: 0.0352 - val_loss: 0.0289 - val_angle_output_loss: 0.0088 - val_speed_output_loss: 0.0202 - val_angle_output_mae: 0.0669 - val_speed_output_mae: 0.0391
# Epoch 44/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0066 - angle_output_loss: 0.0042 - speed_output_loss: 0.0024 - angle_output_mae: 0.0500 - speed_output_mae: 0.0349 - val_loss: 0.0301 - val_angle_output_loss: 0.0088 - val_speed_output_loss: 0.0213 - val_angle_output_mae: 0.0668 - val_speed_output_mae: 0.0430
# Epoch 45/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0116 - angle_output_loss: 0.0058 - speed_output_loss: 0.0058 - angle_output_mae: 0.0576 - speed_output_mae: 0.0427 - val_loss: 0.0350 - val_angle_output_loss: 0.0098 - val_speed_output_loss: 0.0252 - val_angle_output_mae: 0.0714 - val_speed_output_mae: 0.0512
# Epoch 46/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0097 - angle_output_loss: 0.0056 - speed_output_loss: 0.0041 - angle_output_mae: 0.0569 - speed_output_mae: 0.0400 - val_loss: 0.0309 - val_angle_output_loss: 0.0090 - val_speed_output_loss: 0.0219 - val_angle_output_mae: 0.0685 - val_speed_output_mae: 0.0430
# Epoch 47/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0072 - angle_output_loss: 0.0047 - speed_output_loss: 0.0026 - angle_output_mae: 0.0527 - speed_output_mae: 0.0351 - val_loss: 0.0324 - val_angle_output_loss: 0.0089 - val_speed_output_loss: 0.0235 - val_angle_output_mae: 0.0682 - val_speed_output_mae: 0.0491
# Epoch 48/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0069 - angle_output_loss: 0.0043 - speed_output_loss: 0.0026 - angle_output_mae: 0.0507 - speed_output_mae: 0.0343 - val_loss: 0.0301 - val_angle_output_loss: 0.0094 - val_speed_output_loss: 0.0208 - val_angle_output_mae: 0.0689 - val_speed_output_mae: 0.0356
# Epoch 49/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0063 - angle_output_loss: 0.0041 - speed_output_loss: 0.0022 - angle_output_mae: 0.0492 - speed_output_mae: 0.0326 - val_loss: 0.0340 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0244 - val_angle_output_mae: 0.0705 - val_speed_output_mae: 0.0494
# Epoch 50/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0076 - angle_output_loss: 0.0047 - speed_output_loss: 0.0029 - angle_output_mae: 0.0529 - speed_output_mae: 0.0350 - val_loss: 0.0335 - val_angle_output_loss: 0.0095 - val_speed_output_loss: 0.0240 - val_angle_output_mae: 0.0717 - val_speed_output_mae: 0.0450
# Epoch 51/100
# 345/345 [==============================] - 14s 39ms/step - loss: 0.0069 - angle_output_loss: 0.0043 - speed_output_loss: 0.0026 - angle_output_mae: 0.0507 - speed_output_mae: 0.0347 - val_loss: 0.0331 - val_angle_output_loss: 0.0093 - val_speed_output_loss: 0.0239 - val_angle_output_mae: 0.0694 - val_speed_output_mae: 0.0412
# Epoch 52/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0065 - angle_output_loss: 0.0042 - speed_output_loss: 0.0023 - angle_output_mae: 0.0501 - speed_output_mae: 0.0327 - val_loss: 0.0321 - val_angle_output_loss: 0.0093 - val_speed_output_loss: 0.0228 - val_angle_output_mae: 0.0695 - val_speed_output_mae: 0.0414
# Epoch 53/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0086 - angle_output_loss: 0.0051 - speed_output_loss: 0.0034 - angle_output_mae: 0.0549 - speed_output_mae: 0.0359 - val_loss: 0.0324 - val_angle_output_loss: 0.0091 - val_speed_output_loss: 0.0233 - val_angle_output_mae: 0.0676 - val_speed_output_mae: 0.0384
# Epoch 54/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0073 - angle_output_loss: 0.0045 - speed_output_loss: 0.0028 - angle_output_mae: 0.0518 - speed_output_mae: 0.0337 - val_loss: 0.0343 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0247 - val_angle_output_mae: 0.0704 - val_speed_output_mae: 0.0438
# Epoch 55/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0133 - angle_output_loss: 0.0065 - speed_output_loss: 0.0069 - angle_output_mae: 0.0603 - speed_output_mae: 0.0429 - val_loss: 0.0396 - val_angle_output_loss: 0.0098 - val_speed_output_loss: 0.0298 - val_angle_output_mae: 0.0709 - val_speed_output_mae: 0.0703
# Epoch 56/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0098 - angle_output_loss: 0.0055 - speed_output_loss: 0.0043 - angle_output_mae: 0.0566 - speed_output_mae: 0.0385 - val_loss: 0.0323 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0231 - val_angle_output_mae: 0.0684 - val_speed_output_mae: 0.0424
# Epoch 57/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0075 - angle_output_loss: 0.0045 - speed_output_loss: 0.0030 - angle_output_mae: 0.0518 - speed_output_mae: 0.0346 - val_loss: 0.0313 - val_angle_output_loss: 0.0094 - val_speed_output_loss: 0.0219 - val_angle_output_mae: 0.0686 - val_speed_output_mae: 0.0464
# Epoch 58/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0062 - angle_output_loss: 0.0040 - speed_output_loss: 0.0022 - angle_output_mae: 0.0490 - speed_output_mae: 0.0322 - val_loss: 0.0314 - val_angle_output_loss: 0.0091 - val_speed_output_loss: 0.0224 - val_angle_output_mae: 0.0674 - val_speed_output_mae: 0.0388
# Epoch 59/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0057 - angle_output_loss: 0.0037 - speed_output_loss: 0.0020 - angle_output_mae: 0.0465 - speed_output_mae: 0.0313 - val_loss: 0.0313 - val_angle_output_loss: 0.0090 - val_speed_output_loss: 0.0223 - val_angle_output_mae: 0.0667 - val_speed_output_mae: 0.0424
# Epoch 60/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0053 - angle_output_loss: 0.0034 - speed_output_loss: 0.0019 - angle_output_mae: 0.0445 - speed_output_mae: 0.0312 - val_loss: 0.0303 - val_angle_output_loss: 0.0094 - val_speed_output_loss: 0.0209 - val_angle_output_mae: 0.0691 - val_speed_output_mae: 0.0380
# Epoch 61/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0050 - angle_output_loss: 0.0032 - speed_output_loss: 0.0018 - angle_output_mae: 0.0437 - speed_output_mae: 0.0301 - val_loss: 0.0312 - val_angle_output_loss: 0.0090 - val_speed_output_loss: 0.0222 - val_angle_output_mae: 0.0674 - val_speed_output_mae: 0.0362
# Epoch 62/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0049 - angle_output_loss: 0.0031 - speed_output_loss: 0.0018 - angle_output_mae: 0.0427 - speed_output_mae: 0.0304 - val_loss: 0.0312 - val_angle_output_loss: 0.0093 - val_speed_output_loss: 0.0219 - val_angle_output_mae: 0.0691 - val_speed_output_mae: 0.0438
# Epoch 63/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0051 - angle_output_loss: 0.0031 - speed_output_loss: 0.0019 - angle_output_mae: 0.0427 - speed_output_mae: 0.0309 - val_loss: 0.0309 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0213 - val_angle_output_mae: 0.0700 - val_speed_output_mae: 0.0389
# Epoch 64/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0048 - angle_output_loss: 0.0030 - speed_output_loss: 0.0018 - angle_output_mae: 0.0420 - speed_output_mae: 0.0304 - val_loss: 0.0302 - val_angle_output_loss: 0.0090 - val_speed_output_loss: 0.0212 - val_angle_output_mae: 0.0676 - val_speed_output_mae: 0.0365
# Epoch 65/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0086 - angle_output_loss: 0.0041 - speed_output_loss: 0.0045 - angle_output_mae: 0.0481 - speed_output_mae: 0.0356 - val_loss: 0.0524 - val_angle_output_loss: 0.0112 - val_speed_output_loss: 0.0412 - val_angle_output_mae: 0.0773 - val_speed_output_mae: 0.0753
# Epoch 66/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0166 - angle_output_loss: 0.0069 - speed_output_loss: 0.0097 - angle_output_mae: 0.0617 - speed_output_mae: 0.0474 - val_loss: 0.0321 - val_angle_output_loss: 0.0095 - val_speed_output_loss: 0.0226 - val_angle_output_mae: 0.0715 - val_speed_output_mae: 0.0426
# Epoch 67/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0114 - angle_output_loss: 0.0058 - speed_output_loss: 0.0056 - angle_output_mae: 0.0572 - speed_output_mae: 0.0401 - val_loss: 0.0323 - val_angle_output_loss: 0.0091 - val_speed_output_loss: 0.0232 - val_angle_output_mae: 0.0677 - val_speed_output_mae: 0.0416
# Epoch 68/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0068 - angle_output_loss: 0.0044 - speed_output_loss: 0.0024 - angle_output_mae: 0.0505 - speed_output_mae: 0.0327 - val_loss: 0.0334 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0242 - val_angle_output_mae: 0.0674 - val_speed_output_mae: 0.0381
# Epoch 69/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0056 - angle_output_loss: 0.0036 - speed_output_loss: 0.0020 - angle_output_mae: 0.0461 - speed_output_mae: 0.0305 - val_loss: 0.0320 - val_angle_output_loss: 0.0091 - val_speed_output_loss: 0.0229 - val_angle_output_mae: 0.0678 - val_speed_output_mae: 0.0373
# Epoch 70/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0052 - angle_output_loss: 0.0033 - speed_output_loss: 0.0020 - angle_output_mae: 0.0440 - speed_output_mae: 0.0308 - val_loss: 0.0320 - val_angle_output_loss: 0.0094 - val_speed_output_loss: 0.0226 - val_angle_output_mae: 0.0685 - val_speed_output_mae: 0.0374
# Epoch 71/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0058 - angle_output_loss: 0.0035 - speed_output_loss: 0.0022 - angle_output_mae: 0.0456 - speed_output_mae: 0.0316 - val_loss: 0.0328 - val_angle_output_loss: 0.0093 - val_speed_output_loss: 0.0235 - val_angle_output_mae: 0.0685 - val_speed_output_mae: 0.0409
# Epoch 72/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0054 - angle_output_loss: 0.0034 - speed_output_loss: 0.0020 - angle_output_mae: 0.0445 - speed_output_mae: 0.0308 - val_loss: 0.0316 - val_angle_output_loss: 0.0091 - val_speed_output_loss: 0.0225 - val_angle_output_mae: 0.0675 - val_speed_output_mae: 0.0374
# Epoch 73/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0053 - angle_output_loss: 0.0033 - speed_output_loss: 0.0020 - angle_output_mae: 0.0435 - speed_output_mae: 0.0309 - val_loss: 0.0339 - val_angle_output_loss: 0.0098 - val_speed_output_loss: 0.0241 - val_angle_output_mae: 0.0699 - val_speed_output_mae: 0.0427
# Epoch 74/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0051 - angle_output_loss: 0.0032 - speed_output_loss: 0.0019 - angle_output_mae: 0.0433 - speed_output_mae: 0.0304 - val_loss: 0.0305 - val_angle_output_loss: 0.0093 - val_speed_output_loss: 0.0212 - val_angle_output_mae: 0.0681 - val_speed_output_mae: 0.0343
# Epoch 75/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0054 - angle_output_loss: 0.0034 - speed_output_loss: 0.0020 - angle_output_mae: 0.0447 - speed_output_mae: 0.0310 - val_loss: 0.0414 - val_angle_output_loss: 0.0109 - val_speed_output_loss: 0.0305 - val_angle_output_mae: 0.0751 - val_speed_output_mae: 0.0570
# Epoch 76/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0145 - angle_output_loss: 0.0066 - speed_output_loss: 0.0079 - angle_output_mae: 0.0608 - speed_output_mae: 0.0441 - val_loss: 0.0331 - val_angle_output_loss: 0.0100 - val_speed_output_loss: 0.0231 - val_angle_output_mae: 0.0718 - val_speed_output_mae: 0.0411
# Epoch 77/100
# 345/345 [==============================] - 15s 43ms/step - loss: 0.0091 - angle_output_loss: 0.0051 - speed_output_loss: 0.0039 - angle_output_mae: 0.0542 - speed_output_mae: 0.0362 - val_loss: 0.0343 - val_angle_output_loss: 0.0102 - val_speed_output_loss: 0.0241 - val_angle_output_mae: 0.0722 - val_speed_output_mae: 0.0405
# Epoch 78/100
# 345/345 [==============================] - 15s 43ms/step - loss: 0.0070 - angle_output_loss: 0.0042 - speed_output_loss: 0.0028 - angle_output_mae: 0.0498 - speed_output_mae: 0.0332 - val_loss: 0.0330 - val_angle_output_loss: 0.0094 - val_speed_output_loss: 0.0235 - val_angle_output_mae: 0.0687 - val_speed_output_mae: 0.0358
# Epoch 79/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0055 - angle_output_loss: 0.0035 - speed_output_loss: 0.0019 - angle_output_mae: 0.0455 - speed_output_mae: 0.0305 - val_loss: 0.0317 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0222 - val_angle_output_mae: 0.0690 - val_speed_output_mae: 0.0334
# Epoch 80/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0049 - angle_output_loss: 0.0031 - speed_output_loss: 0.0018 - angle_output_mae: 0.0432 - speed_output_mae: 0.0304 - val_loss: 0.0320 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0227 - val_angle_output_mae: 0.0678 - val_speed_output_mae: 0.0394
# Epoch 81/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0047 - angle_output_loss: 0.0029 - speed_output_loss: 0.0017 - angle_output_mae: 0.0414 - speed_output_mae: 0.0306 - val_loss: 0.0315 - val_angle_output_loss: 0.0095 - val_speed_output_loss: 0.0220 - val_angle_output_mae: 0.0691 - val_speed_output_mae: 0.0350
# Epoch 82/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0043 - angle_output_loss: 0.0027 - speed_output_loss: 0.0016 - angle_output_mae: 0.0402 - speed_output_mae: 0.0295 - val_loss: 0.0312 - val_angle_output_loss: 0.0093 - val_speed_output_loss: 0.0219 - val_angle_output_mae: 0.0684 - val_speed_output_mae: 0.0482
# Epoch 83/100
# 345/345 [==============================] - 15s 42ms/step - loss: 0.0043 - angle_output_loss: 0.0026 - speed_output_loss: 0.0016 - angle_output_mae: 0.0393 - speed_output_mae: 0.0294 - val_loss: 0.0319 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0223 - val_angle_output_mae: 0.0702 - val_speed_output_mae: 0.0352
# Epoch 84/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0044 - angle_output_loss: 0.0027 - speed_output_loss: 0.0016 - angle_output_mae: 0.0398 - speed_output_mae: 0.0294 - val_loss: 0.0323 - val_angle_output_loss: 0.0097 - val_speed_output_loss: 0.0226 - val_angle_output_mae: 0.0710 - val_speed_output_mae: 0.0346
# Epoch 85/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0043 - angle_output_loss: 0.0026 - speed_output_loss: 0.0017 - angle_output_mae: 0.0390 - speed_output_mae: 0.0294 - val_loss: 0.0308 - val_angle_output_loss: 0.0090 - val_speed_output_loss: 0.0218 - val_angle_output_mae: 0.0674 - val_speed_output_mae: 0.0380
# Epoch 86/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0129 - angle_output_loss: 0.0058 - speed_output_loss: 0.0071 - angle_output_mae: 0.0575 - speed_output_mae: 0.0426 - val_loss: 0.0368 - val_angle_output_loss: 0.0101 - val_speed_output_loss: 0.0268 - val_angle_output_mae: 0.0712 - val_speed_output_mae: 0.0465
# Epoch 87/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0088 - angle_output_loss: 0.0051 - speed_output_loss: 0.0037 - angle_output_mae: 0.0540 - speed_output_mae: 0.0359 - val_loss: 0.0346 - val_angle_output_loss: 0.0093 - val_speed_output_loss: 0.0252 - val_angle_output_mae: 0.0685 - val_speed_output_mae: 0.0384
# Epoch 88/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0060 - angle_output_loss: 0.0038 - speed_output_loss: 0.0023 - angle_output_mae: 0.0472 - speed_output_mae: 0.0313 - val_loss: 0.0346 - val_angle_output_loss: 0.0095 - val_speed_output_loss: 0.0251 - val_angle_output_mae: 0.0685 - val_speed_output_mae: 0.0432
# Epoch 89/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0050 - angle_output_loss: 0.0031 - speed_output_loss: 0.0019 - angle_output_mae: 0.0429 - speed_output_mae: 0.0306 - val_loss: 0.0334 - val_angle_output_loss: 0.0089 - val_speed_output_loss: 0.0246 - val_angle_output_mae: 0.0670 - val_speed_output_mae: 0.0445
# Epoch 90/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0045 - angle_output_loss: 0.0028 - speed_output_loss: 0.0017 - angle_output_mae: 0.0406 - speed_output_mae: 0.0300 - val_loss: 0.0325 - val_angle_output_loss: 0.0093 - val_speed_output_loss: 0.0232 - val_angle_output_mae: 0.0683 - val_speed_output_mae: 0.0364
# Epoch 91/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0044 - angle_output_loss: 0.0027 - speed_output_loss: 0.0017 - angle_output_mae: 0.0397 - speed_output_mae: 0.0299 - val_loss: 0.0313 - val_angle_output_loss: 0.0091 - val_speed_output_loss: 0.0222 - val_angle_output_mae: 0.0683 - val_speed_output_mae: 0.0344
# Epoch 92/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0041 - angle_output_loss: 0.0025 - speed_output_loss: 0.0016 - angle_output_mae: 0.0379 - speed_output_mae: 0.0291 - val_loss: 0.0338 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0242 - val_angle_output_mae: 0.0704 - val_speed_output_mae: 0.0393
# Epoch 93/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0039 - angle_output_loss: 0.0024 - speed_output_loss: 0.0016 - angle_output_mae: 0.0370 - speed_output_mae: 0.0295 - val_loss: 0.0321 - val_angle_output_loss: 0.0091 - val_speed_output_loss: 0.0231 - val_angle_output_mae: 0.0680 - val_speed_output_mae: 0.0449
# Epoch 94/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0042 - angle_output_loss: 0.0025 - speed_output_loss: 0.0016 - angle_output_mae: 0.0379 - speed_output_mae: 0.0294 - val_loss: 0.0339 - val_angle_output_loss: 0.0103 - val_speed_output_loss: 0.0236 - val_angle_output_mae: 0.0722 - val_speed_output_mae: 0.0428
# Epoch 95/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0154 - angle_output_loss: 0.0068 - speed_output_loss: 0.0086 - angle_output_mae: 0.0616 - speed_output_mae: 0.0455 - val_loss: 0.0371 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0275 - val_angle_output_mae: 0.0698 - val_speed_output_mae: 0.0502
# Epoch 96/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0081 - angle_output_loss: 0.0046 - speed_output_loss: 0.0035 - angle_output_mae: 0.0516 - speed_output_mae: 0.0348 - val_loss: 0.0314 - val_angle_output_loss: 0.0094 - val_speed_output_loss: 0.0220 - val_angle_output_mae: 0.0685 - val_speed_output_mae: 0.0382
# Epoch 97/100
# 345/345 [==============================] - 14s 42ms/step - loss: 0.0059 - angle_output_loss: 0.0037 - speed_output_loss: 0.0023 - angle_output_mae: 0.0464 - speed_output_mae: 0.0313 - val_loss: 0.0375 - val_angle_output_loss: 0.0095 - val_speed_output_loss: 0.0281 - val_angle_output_mae: 0.0690 - val_speed_output_mae: 0.0498
# Epoch 98/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0066 - angle_output_loss: 0.0039 - speed_output_loss: 0.0026 - angle_output_mae: 0.0479 - speed_output_mae: 0.0326 - val_loss: 0.0331 - val_angle_output_loss: 0.0093 - val_speed_output_loss: 0.0238 - val_angle_output_mae: 0.0681 - val_speed_output_mae: 0.0409
# Epoch 99/100
# 345/345 [==============================] - 14s 41ms/step - loss: 0.0050 - angle_output_loss: 0.0032 - speed_output_loss: 0.0018 - angle_output_mae: 0.0437 - speed_output_mae: 0.0300 - val_loss: 0.0354 - val_angle_output_loss: 0.0095 - val_speed_output_loss: 0.0259 - val_angle_output_mae: 0.0686 - val_speed_output_mae: 0.0397
# Epoch 100/100
# 345/345 [==============================] - 14s 40ms/step - loss: 0.0045 - angle_output_loss: 0.0029 - speed_output_loss: 0.0016 - angle_output_mae: 0.0407 - speed_output_mae: 0.0298 - val_loss: 0.0323 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0231 - val_angle_output_mae: 0.0673 - val_speed_output_mae: 0.0426

# %%
# make predictions on the test set
test_predictions = best_model.predict(test_images)

# get the steering angle and speed predictions separately
test_steering_predictions = test_predictions[0]
test_speed_predictions = test_predictions[1]

# speed adjustment
if np.min(test_speed_predictions) < 0:
    test_speed_predictions = test_speed_predictions - np.min(test_speed_predictions) #if there is negative num in spd column
    max_val = np.max(test_speed_predictions)      
    normalized_arr_spd = test_speed_predictions / max_val
    test_speed_predictions = np.where(normalized_arr_spd >= 0.5, 1, 0)
else:
    max_val = np.max(test_speed_predictions)      
    normalized_arr_spd = test_speed_predictions / max_val
    test_speed_predictions = np.where(normalized_arr_spd >= 0.5, 1, 0)

submission_df = pd.DataFrame({
    'image_id': test_ids.flatten(),
    'angle': test_steering_predictions.flatten(),
    'speed': test_speed_predictions.flatten()
})
submission_df.to_csv('output/submission.csv', index=False)
# Out:
# 32/32 [==============================] - 1s 19ms/step

# %%
# speed adjustment
if np.min(test_speed_predictions) < 0:
    test_speed_predictions = test_speed_predictions - np.min(test_speed_predictions) #if there is negative num in spd column
    max_val = np.max(test_speed_predictions)      
    normalized_arr_spd = test_speed_predictions / max_val
    test_speed_predictions = np.where(normalized_arr_spd >= 0.5, 1, 0)
else:
    max_val = np.max(test_speed_predictions)      
    normalized_arr_spd = test_speed_predictions / max_val
    test_speed_predictions = np.where(normalized_arr_spd >= 0.5, 1, 0)

# %%
pip install opencv-python-headless
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: opencv-python-headless in /environment/miniconda3/lib/python3.7/site-packages (4.5.4.60)
# Requirement already satisfied: numpy>=1.14.5 in /environment/miniconda3/lib/python3.7/site-packages (from opencv-python-headless) (1.21.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: scikit-learn in /environment/miniconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: joblib>=0.11 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-learn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-learn) (1.21.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imgaug
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting imgaug
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/66/b1/af3142c4a85cba6da9f4ebb5ff4e21e2616309552caca5e8acefe9840622/imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      |████████████████████████████████| 948 kB 26.1 MB/s eta 0:00:01
# Collecting Shapely
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1d/a4/931d0780f31f3ea8c4f9ef6464a2825137c5241e6707a5fb03bef760a7eb/shapely-2.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 111.2 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /environment/miniconda3/lib/python3.7/site-packages (from imgaug) (1.7.3)
# Requirement already satisfied: six in /environment/miniconda3/lib/python3.7/site-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /environment/miniconda3/lib/python3.7/site-packages (from imgaug) (1.21.4)
# Requirement already satisfied: matplotlib in /environment/miniconda3/lib/python3.7/site-packages (from imgaug) (3.5.0)
# Requirement already satisfied: opencv-python in /environment/miniconda3/lib/python3.7/site-packages (from imgaug) (4.5.4.60)
# Requirement already satisfied: Pillow in /environment/miniconda3/lib/python3.7/site-packages (from imgaug) (8.4.0)
# Requirement already satisfied: scikit-image>=0.14.2 in /environment/miniconda3/lib/python3.7/site-packages (from imgaug) (0.19.0)
# Requirement already satisfied: imageio in /environment/miniconda3/lib/python3.7/site-packages (from imgaug) (2.13.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image>=0.14.2->imgaug) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image>=0.14.2->imgaug) (21.3)
# Requirement already satisfied: networkx>=2.2 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image>=0.14.2->imgaug) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image>=0.14.2->imgaug) (2021.11.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /environment/miniconda3/lib/python3.7/site-packages (from packaging>=20.0->scikit-image>=0.14.2->imgaug) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->imgaug) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->imgaug) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->imgaug) (4.28.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->imgaug) (1.3.2)
# Requirement already satisfied: setuptools-scm>=4 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->imgaug) (6.3.2)
# Requirement already satisfied: tomli>=1.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib->imgaug) (1.2.2)
# Requirement already satisfied: setuptools in /environment/miniconda3/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib->imgaug) (52.0.0.post20210125)
# Installing collected packages: Shapely, imgaug
# Successfully installed Shapely-2.0.1 imgaug-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# ensemble model b5 b7, K-fold, image augmentation
import numpy as np
import pandas as pd
import cv2
import pickle
import imgaug.augmenters as iaa
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.applications import EfficientNetB7, EfficientNetB5
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint

# Image augmentation
seq = iaa.Sequential([
    iaa.Multiply((0.8, 1.2)),  # Adjust brightness
    iaa.LinearContrast((0.9, 1.1)),  # Adjust contrast
    iaa.AdditiveGaussianNoise(scale=(0, 0.02*255)),  # Add small amount of noise
    iaa.Affine(
        scale={"x": (0.95, 1.05), "y": (0.95, 1.05)},  # Small-scale zoom (±5%)
        rotate=(-3, 3),  # Small rotation (±3°)
        order=[0, 1],  # Nearest neighbour or bilinear interpolation
        mode='reflect'  # Use scikit-image's warping modes
    )
])


# Create models
def create_model(model_name):
    if model_name == 'EfficientNetB7':
        base_model = EfficientNetB7(include_top=False, weights='imagenet', input_shape=(240, 320, 3))
    elif model_name == 'EfficientNetB5':
        base_model = EfficientNetB5(include_top=False, weights='imagenet', input_shape=(240, 320, 3))

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    angle_output = Dense(1, name='angle_output')(x)
    speed_output = Dense(1, name='speed_output')(x)
    
    model = Model(inputs=base_model.input, outputs=[angle_output, speed_output])
    
    optimizer = Adam(learning_rate=0.001)
    loss = {'angle_output': 'mean_squared_error', 'speed_output': 'mean_squared_error'}
    metrics = {'angle_output': 'mae', 'speed_output': 'mae'}
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    
    return model

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * 0.9

lr_scheduler = LearningRateScheduler(scheduler)

# load train dataset
train_df = pd.read_csv('data/training_norm.csv')
train_images = []
for image_id in train_df['image_id']:
    image = cv2.imread(f'data/training_data/training_data/{image_id}.png')
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    train_images.append(image)
train_images = np.array(train_images)
train_angles = np.array(train_df['angle'])
train_speeds = np.array(train_df['speed'])

# Apply image augmentation
train_images = seq(images=train_images)

# load test dataset
test_images = []
for i in range(1, 1021):
    image = cv2.imread(f'data/test_data/test_data/{i}.png')
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    test_images.append(image)
test_images = np.array(test_images)
test_ids = np.arange(1, 1021)

# K-Fold Cross Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
models = []
histories = []  # Add this line to create an empty histories list
fold = 1
model_names = ['EfficientNetB7', 'EfficientNetB5']

for train_index, val_index in kf.split(train_images):
    X_train, X_val = train_images[train_index], train_images[val_index]
    y_train, y_val = train_df[['angle', 'speed']].values[train_index], train_df[['angle', 'speed']].values[val_index]
    
    for model_name in model_names:
        model = create_model(model_name)
        model_checkpoint = ModelCheckpoint(f"model_{model_name}_fold_{fold}_best_val_loss.h5", save_best_only=True, monitor='val_loss', mode='min', verbose=1)
        
        early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1)
        history = model.fit(X_train, [y_train[:, 0], y_train[:, 1]], epochs=100, batch_size=32, validation_data=(X_val, [y_val[:, 0], y_val[:, 1]]), callbacks=[early_stop, lr_scheduler, model_checkpoint])


        models.append(model)
        histories.append(history)  # Add this line to save the history object to the histories list
        print(f"Finished training fold {fold} with model {model_name}")
    
    fold += 1


for i, model in enumerate(models):
    model.save(f"model_{i}.h5")


model_weights = [1 / len(models)] * len(models)
with open("model_weights.pkl", "wb") as f:
    pickle.dump(model_weights, f)


for i, history in enumerate(histories):
    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title(f'Fold {i + 1} Loss')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['angle_output_mae'], label='Training Angle MAE')
    plt.plot(history.history['speed_output_mae'], label='Training Speed MAE')
    plt.plot(history.history['val_angle_output_mae'], label='Validation Angle MAE')
    plt.plot(history.history['val_speed_output_mae'], label='Validation Speed MAE')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Absolute Error')
    plt.legend()
    plt.title(f'Fold {i + 1} Mean Absolute Error')

    plt.show()


best_model_index = np.argmin([history.history['val_loss'][-1] for history in histories])
best_model = models[best_model_index]
best_model.save("best_model.h5")

# Average the predictions of all models
test_predictions = [model.predict(test_images) for model in models]
test_angle_predictions = np.mean([predictions[0] for predictions in test_predictions], axis=0)
test_speed_predictions = np.mean([predictions[1] for predictions in test_predictions], axis=0)

# speed adjustment
if np.min(test_speed_predictions) < 0:
    test_speed_predictions = test_speed_predictions - np.min(test_speed_predictions)  # if there is a negative num in the spd column
    max_val = np.max(test_speed_predictions)      
    normalized_arr_spd = test_speed_predictions / max_val
    test_speed_predictions = np.where(normalized_arr_spd >= 0.5, 1, 0)
else:
    max_val = np.max(test_speed_predictions)      
    normalized_arr_spd = test_speed_predictions / max_val
    test_speed_predictions = np.where(normalized_arr_spd >= 0.5, 1, 0)

submission_df = pd.DataFrame({
    'image_id': test_ids.flatten(),
    'angle': test_angle_predictions.flatten(),
    'speed': test_speed_predictions.flatten()
})
submission_df.to_csv('submission ensemble.csv', index=False)
# Out:
# 2023-03-31 06:21:47.931757: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 06:21:48.022322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 06:21:48.022691: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 06:21:48.025061: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-31 06:21:48.028517: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 06:21:48.028869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 06:21:48.029200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 06:21:49.414787: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 06:21:49.415101: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 06:21:49.415382: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-31 06:21:49.416308: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46719 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:10:00.0, compute capability: 8.6
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 27s 0us/step
# 258088960/258076736 [==============================] - 27s 0us/step
# Epoch 1/100
# 2023-03-31 06:22:51.237686: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8101
# 2023-03-31 06:22:55.813049: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 345/345 [==============================] - 416s 1s/step - loss: 0.1125 - angle_output_loss: 0.0397 - speed_output_loss: 0.0727 - angle_output_mae: 0.1433 - speed_output_mae: 0.1807 - val_loss: 0.0386 - val_angle_output_loss: 0.0135 - val_speed_output_loss: 0.0251 - val_angle_output_mae: 0.0866 - val_speed_output_mae: 0.1040 - lr: 0.0010
# Epoch 2/100
# 345/345 [==============================] - 378s 1s/step - loss: 0.0406 - angle_output_loss: 0.0151 - speed_output_loss: 0.0255 - angle_output_mae: 0.0945 - speed_output_mae: 0.1043 - val_loss: 0.0304 - val_angle_output_loss: 0.0105 - val_speed_output_loss: 0.0199 - val_angle_output_mae: 0.0758 - val_speed_output_mae: 0.0506 - lr: 0.0010
# Epoch 3/100
# 345/345 [==============================] - 375s 1s/step - loss: 0.0330 - angle_output_loss: 0.0125 - speed_output_loss: 0.0204 - angle_output_mae: 0.0853 - speed_output_mae: 0.0913 - val_loss: 0.0346 - val_angle_output_loss: 0.0097 - val_speed_output_loss: 0.0249 - val_angle_output_mae: 0.0720 - val_speed_output_mae: 0.0548 - lr: 0.0010
# Epoch 4/100
# 345/345 [==============================] - 377s 1s/step - loss: 0.0279 - angle_output_loss: 0.0111 - speed_output_loss: 0.0168 - angle_output_mae: 0.0804 - speed_output_mae: 0.0831 - val_loss: 0.0323 - val_angle_output_loss: 0.0094 - val_speed_output_loss: 0.0229 - val_angle_output_mae: 0.0679 - val_speed_output_mae: 0.0568 - lr: 0.0010
# Epoch 5/100
# 345/345 [==============================] - 378s 1s/step - loss: 0.0251 - angle_output_loss: 0.0103 - speed_output_loss: 0.0149 - angle_output_mae: 0.0767 - speed_output_mae: 0.0783 - val_loss: 0.0372 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0279 - val_angle_output_mae: 0.0690 - val_speed_output_mae: 0.0640 - lr: 0.0010
# Epoch 6/100
# 345/345 [==============================] - 377s 1s/step - loss: 0.0269 - angle_output_loss: 0.0098 - speed_output_loss: 0.0171 - angle_output_mae: 0.0750 - speed_output_mae: 0.0797 - val_loss: 0.0329 - val_angle_output_loss: 0.0103 - val_speed_output_loss: 0.0226 - val_angle_output_mae: 0.0723 - val_speed_output_mae: 0.0852 - lr: 0.0010
# Epoch 7/100
# 345/345 [==============================] - 378s 1s/step - loss: 0.0271 - angle_output_loss: 0.0096 - speed_output_loss: 0.0174 - angle_output_mae: 0.0742 - speed_output_mae: 0.0812 - val_loss: 0.0444 - val_angle_output_loss: 0.0139 - val_speed_output_loss: 0.0305 - val_angle_output_mae: 0.0777 - val_speed_output_mae: 0.0559 - lr: 0.0010
# Epoch 00007: early stopping
# Finished training fold 1 with model EfficientNetB7
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115269632/115263384 [==============================] - 16s 0us/step
# 115277824/115263384 [==============================] - 16s 0us/step
# Epoch 1/100
# 345/345 [==============================] - 254s 681ms/step - loss: 0.0951 - angle_output_loss: 0.0339 - speed_output_loss: 0.0611 - angle_output_mae: 0.1337 - speed_output_mae: 0.1713 - val_loss: 0.0279 - val_angle_output_loss: 0.0110 - val_speed_output_loss: 0.0168 - val_angle_output_mae: 0.0778 - val_speed_output_mae: 0.0569 - lr: 0.0010
# Epoch 2/100
# 345/345 [==============================] - 228s 661ms/step - loss: 0.0375 - angle_output_loss: 0.0147 - speed_output_loss: 0.0228 - angle_output_mae: 0.0934 - speed_output_mae: 0.0985 - val_loss: 0.0265 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0169 - val_angle_output_mae: 0.0716 - val_speed_output_mae: 0.0488 - lr: 0.0010
# Epoch 3/100
# 345/345 [==============================] - 228s 662ms/step - loss: 0.0297 - angle_output_loss: 0.0117 - speed_output_loss: 0.0180 - angle_output_mae: 0.0830 - speed_output_mae: 0.0876 - val_loss: 0.0266 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0174 - val_angle_output_mae: 0.0714 - val_speed_output_mae: 0.0395 - lr: 0.0010
# Epoch 4/100
# 345/345 [==============================] - 229s 664ms/step - loss: 0.0269 - angle_output_loss: 0.0107 - speed_output_loss: 0.0162 - angle_output_mae: 0.0789 - speed_output_mae: 0.0798 - val_loss: 0.0321 - val_angle_output_loss: 0.0098 - val_speed_output_loss: 0.0223 - val_angle_output_mae: 0.0674 - val_speed_output_mae: 0.0410 - lr: 0.0010
# Epoch 5/100
# 345/345 [==============================] - 231s 668ms/step - loss: 0.0257 - angle_output_loss: 0.0098 - speed_output_loss: 0.0159 - angle_output_mae: 0.0756 - speed_output_mae: 0.0780 - val_loss: 0.0218 - val_angle_output_loss: 0.0080 - val_speed_output_loss: 0.0138 - val_angle_output_mae: 0.0635 - val_speed_output_mae: 0.0339 - lr: 0.0010
# Epoch 6/100
# 345/345 [==============================] - 230s 666ms/step - loss: 0.0226 - angle_output_loss: 0.0091 - speed_output_loss: 0.0134 - angle_output_mae: 0.0731 - speed_output_mae: 0.0723 - val_loss: 0.0227 - val_angle_output_loss: 0.0088 - val_speed_output_loss: 0.0139 - val_angle_output_mae: 0.0664 - val_speed_output_mae: 0.0344 - lr: 0.0010
# Epoch 7/100
# 345/345 [==============================] - 225s 653ms/step - loss: 0.0214 - angle_output_loss: 0.0088 - speed_output_loss: 0.0126 - angle_output_mae: 0.0711 - speed_output_mae: 0.0693 - val_loss: 0.0322 - val_angle_output_loss: 0.0102 - val_speed_output_loss: 0.0221 - val_angle_output_mae: 0.0773 - val_speed_output_mae: 0.0555 - lr: 0.0010
# Epoch 8/100
# 345/345 [==============================] - 230s 667ms/step - loss: 0.0224 - angle_output_loss: 0.0089 - speed_output_loss: 0.0136 - angle_output_mae: 0.0715 - speed_output_mae: 0.0709 - val_loss: 0.0284 - val_angle_output_loss: 0.0079 - val_speed_output_loss: 0.0205 - val_angle_output_mae: 0.0636 - val_speed_output_mae: 0.0811 - lr: 0.0010
# Epoch 9/100
# 345/345 [==============================] - 231s 669ms/step - loss: 0.0228 - angle_output_loss: 0.0089 - speed_output_loss: 0.0139 - angle_output_mae: 0.0706 - speed_output_mae: 0.0715 - val_loss: 0.0317 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0226 - val_angle_output_mae: 0.0698 - val_speed_output_mae: 0.0486 - lr: 0.0010
# Epoch 10/100
# 345/345 [==============================] - 233s 676ms/step - loss: 0.0228 - angle_output_loss: 0.0087 - speed_output_loss: 0.0142 - angle_output_mae: 0.0700 - speed_output_mae: 0.0707 - val_loss: 0.0296 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0205 - val_angle_output_mae: 0.0673 - val_speed_output_mae: 0.0561 - lr: 0.0010
# Epoch 00010: early stopping
# Finished training fold 1 with model EfficientNetB5
# Epoch 1/100
# 345/345 [==============================] - 413s 1s/step - loss: 0.1058 - angle_output_loss: 0.0376 - speed_output_loss: 0.0681 - angle_output_mae: 0.1365 - speed_output_mae: 0.1757 - val_loss: 0.0380 - val_angle_output_loss: 0.0149 - val_speed_output_loss: 0.0231 - val_angle_output_mae: 0.0960 - val_speed_output_mae: 0.1157 - lr: 0.0010
# Epoch 2/100
# 345/345 [==============================] - 382s 1s/step - loss: 0.0382 - angle_output_loss: 0.0149 - speed_output_loss: 0.0234 - angle_output_mae: 0.0932 - speed_output_mae: 0.1009 - val_loss: 0.0578 - val_angle_output_loss: 0.0135 - val_speed_output_loss: 0.0443 - val_angle_output_mae: 0.0906 - val_speed_output_mae: 0.1704 - lr: 0.0010
# Epoch 3/100
# 345/345 [==============================] - 382s 1s/step - loss: 0.0360 - angle_output_loss: 0.0130 - speed_output_loss: 0.0230 - angle_output_mae: 0.0872 - speed_output_mae: 0.0950 - val_loss: 0.0218 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0126 - val_angle_output_mae: 0.0704 - val_speed_output_mae: 0.0517 - lr: 0.0010
# Epoch 4/100
# 345/345 [==============================] - 382s 1s/step - loss: 0.0280 - angle_output_loss: 0.0109 - speed_output_loss: 0.0170 - angle_output_mae: 0.0801 - speed_output_mae: 0.0811 - val_loss: 0.0213 - val_angle_output_loss: 0.0101 - val_speed_output_loss: 0.0112 - val_angle_output_mae: 0.0755 - val_speed_output_mae: 0.0381 - lr: 0.0010
# Epoch 5/100
# 345/345 [==============================] - 379s 1s/step - loss: 0.0278 - angle_output_loss: 0.0104 - speed_output_loss: 0.0173 - angle_output_mae: 0.0780 - speed_output_mae: 0.0801 - val_loss: 0.0349 - val_angle_output_loss: 0.0108 - val_speed_output_loss: 0.0241 - val_angle_output_mae: 0.0788 - val_speed_output_mae: 0.1010 - lr: 0.0010
# Epoch 6/100
# 345/345 [==============================] - 384s 1s/step - loss: 0.0285 - angle_output_loss: 0.0103 - speed_output_loss: 0.0182 - angle_output_mae: 0.0771 - speed_output_mae: 0.0805 - val_loss: 0.0183 - val_angle_output_loss: 0.0080 - val_speed_output_loss: 0.0103 - val_angle_output_mae: 0.0646 - val_speed_output_mae: 0.0355 - lr: 0.0010
# Epoch 7/100
# 345/345 [==============================] - 383s 1s/step - loss: 0.0250 - angle_output_loss: 0.0096 - speed_output_loss: 0.0154 - angle_output_mae: 0.0735 - speed_output_mae: 0.0743 - val_loss: 0.0189 - val_angle_output_loss: 0.0083 - val_speed_output_loss: 0.0107 - val_angle_output_mae: 0.0667 - val_speed_output_mae: 0.0372 - lr: 0.0010
# Epoch 8/100
# 345/345 [==============================] - 381s 1s/step - loss: 0.0215 - angle_output_loss: 0.0089 - speed_output_loss: 0.0126 - angle_output_mae: 0.0715 - speed_output_mae: 0.0691 - val_loss: 0.0223 - val_angle_output_loss: 0.0081 - val_speed_output_loss: 0.0141 - val_angle_output_mae: 0.0671 - val_speed_output_mae: 0.0753 - lr: 0.0010
# Epoch 9/100
# 345/345 [==============================] - 383s 1s/step - loss: 0.0212 - angle_output_loss: 0.0082 - speed_output_loss: 0.0130 - angle_output_mae: 0.0683 - speed_output_mae: 0.0684 - val_loss: 0.0225 - val_angle_output_loss: 0.0089 - val_speed_output_loss: 0.0136 - val_angle_output_mae: 0.0659 - val_speed_output_mae: 0.0497 - lr: 0.0010
# Epoch 10/100
# 345/345 [==============================] - 383s 1s/step - loss: 0.0227 - angle_output_loss: 0.0086 - speed_output_loss: 0.0141 - angle_output_mae: 0.0691 - speed_output_mae: 0.0700 - val_loss: 0.0723 - val_angle_output_loss: 0.0095 - val_speed_output_loss: 0.0627 - val_angle_output_mae: 0.0717 - val_speed_output_mae: 0.1227 - lr: 0.0010
# Epoch 11/100
# 345/345 [==============================] - 382s 1s/step - loss: 0.0198 - angle_output_loss: 0.0084 - speed_output_loss: 0.0113 - angle_output_mae: 0.0688 - speed_output_mae: 0.0639 - val_loss: 0.0179 - val_angle_output_loss: 0.0082 - val_speed_output_loss: 0.0097 - val_angle_output_mae: 0.0660 - val_speed_output_mae: 0.0325 - lr: 9.0000e-04
# Epoch 12/100
# 345/345 [==============================] - 381s 1s/step - loss: 0.0175 - angle_output_loss: 0.0074 - speed_output_loss: 0.0102 - angle_output_mae: 0.0648 - speed_output_mae: 0.0602 - val_loss: 0.0157 - val_angle_output_loss: 0.0077 - val_speed_output_loss: 0.0080 - val_angle_output_mae: 0.0615 - val_speed_output_mae: 0.0387 - lr: 8.1000e-04
# Epoch 13/100
# 345/345 [==============================] - 380s 1s/step - loss: 0.0141 - angle_output_loss: 0.0069 - speed_output_loss: 0.0072 - angle_output_mae: 0.0628 - speed_output_mae: 0.0539 - val_loss: 0.0170 - val_angle_output_loss: 0.0070 - val_speed_output_loss: 0.0099 - val_angle_output_mae: 0.0582 - val_speed_output_mae: 0.0265 - lr: 7.2900e-04
# Epoch 14/100
# 345/345 [==============================] - 382s 1s/step - loss: 0.0132 - angle_output_loss: 0.0067 - speed_output_loss: 0.0066 - angle_output_mae: 0.0619 - speed_output_mae: 0.0526 - val_loss: 0.0171 - val_angle_output_loss: 0.0085 - val_speed_output_loss: 0.0086 - val_angle_output_mae: 0.0640 - val_speed_output_mae: 0.0229 - lr: 6.5610e-04
# Epoch 15/100
# 345/345 [==============================] - 385s 1s/step - loss: 0.0136 - angle_output_loss: 0.0065 - speed_output_loss: 0.0071 - angle_output_mae: 0.0610 - speed_output_mae: 0.0533 - val_loss: 0.0177 - val_angle_output_loss: 0.0074 - val_speed_output_loss: 0.0103 - val_angle_output_mae: 0.0618 - val_speed_output_mae: 0.0403 - lr: 5.9049e-04
# Epoch 16/100
# 345/345 [==============================] - 383s 1s/step - loss: 0.0133 - angle_output_loss: 0.0066 - speed_output_loss: 0.0068 - angle_output_mae: 0.0613 - speed_output_mae: 0.0514 - val_loss: 0.0168 - val_angle_output_loss: 0.0067 - val_speed_output_loss: 0.0100 - val_angle_output_mae: 0.0579 - val_speed_output_mae: 0.0256 - lr: 5.3144e-04
# Epoch 17/100
# 345/345 [==============================] - 382s 1s/step - loss: 0.0125 - angle_output_loss: 0.0061 - speed_output_loss: 0.0064 - angle_output_mae: 0.0595 - speed_output_mae: 0.0502 - val_loss: 0.0172 - val_angle_output_loss: 0.0072 - val_speed_output_loss: 0.0100 - val_angle_output_mae: 0.0586 - val_speed_output_mae: 0.0289 - lr: 4.7830e-04
# Epoch 00017: early stopping
# Finished training fold 2 with model EfficientNetB7
# Epoch 1/100
# 345/345 [==============================] - 251s 679ms/step - loss: 0.0974 - angle_output_loss: 0.0340 - speed_output_loss: 0.0634 - angle_output_mae: 0.1342 - speed_output_mae: 0.1703 - val_loss: 0.0280 - val_angle_output_loss: 0.0140 - val_speed_output_loss: 0.0140 - val_angle_output_mae: 0.0907 - val_speed_output_mae: 0.0577 - lr: 0.0010
# Epoch 2/100
# 345/345 [==============================] - 230s 667ms/step - loss: 0.0394 - angle_output_loss: 0.0154 - speed_output_loss: 0.0239 - angle_output_mae: 0.0958 - speed_output_mae: 0.1032 - val_loss: 0.0377 - val_angle_output_loss: 0.0086 - val_speed_output_loss: 0.0291 - val_angle_output_mae: 0.0679 - val_speed_output_mae: 0.0965 - lr: 0.0010
# Epoch 3/100
# 345/345 [==============================] - 231s 668ms/step - loss: 0.0318 - angle_output_loss: 0.0124 - speed_output_loss: 0.0194 - angle_output_mae: 0.0849 - speed_output_mae: 0.0887 - val_loss: 0.0247 - val_angle_output_loss: 0.0082 - val_speed_output_loss: 0.0165 - val_angle_output_mae: 0.0672 - val_speed_output_mae: 0.0753 - lr: 0.0010
# Epoch 4/100
# 345/345 [==============================] - 230s 667ms/step - loss: 0.0290 - angle_output_loss: 0.0113 - speed_output_loss: 0.0178 - angle_output_mae: 0.0811 - speed_output_mae: 0.0846 - val_loss: 0.0190 - val_angle_output_loss: 0.0080 - val_speed_output_loss: 0.0110 - val_angle_output_mae: 0.0650 - val_speed_output_mae: 0.0428 - lr: 0.0010
# Epoch 5/100
# 345/345 [==============================] - 231s 669ms/step - loss: 0.0265 - angle_output_loss: 0.0099 - speed_output_loss: 0.0167 - angle_output_mae: 0.0756 - speed_output_mae: 0.0804 - val_loss: 0.0220 - val_angle_output_loss: 0.0078 - val_speed_output_loss: 0.0142 - val_angle_output_mae: 0.0628 - val_speed_output_mae: 0.0464 - lr: 0.0010
# Epoch 6/100
# 345/345 [==============================] - 231s 670ms/step - loss: 0.0240 - angle_output_loss: 0.0094 - speed_output_loss: 0.0146 - angle_output_mae: 0.0736 - speed_output_mae: 0.0758 - val_loss: 0.0162 - val_angle_output_loss: 0.0067 - val_speed_output_loss: 0.0095 - val_angle_output_mae: 0.0587 - val_speed_output_mae: 0.0304 - lr: 0.0010
# Epoch 7/100
# 345/345 [==============================] - 230s 668ms/step - loss: 0.0208 - angle_output_loss: 0.0088 - speed_output_loss: 0.0120 - angle_output_mae: 0.0711 - speed_output_mae: 0.0704 - val_loss: 0.0167 - val_angle_output_loss: 0.0071 - val_speed_output_loss: 0.0095 - val_angle_output_mae: 0.0600 - val_speed_output_mae: 0.0326 - lr: 0.0010
# Epoch 8/100
# 345/345 [==============================] - 230s 665ms/step - loss: 0.0235 - angle_output_loss: 0.0087 - speed_output_loss: 0.0148 - angle_output_mae: 0.0709 - speed_output_mae: 0.0742 - val_loss: 0.0269 - val_angle_output_loss: 0.0139 - val_speed_output_loss: 0.0130 - val_angle_output_mae: 0.0931 - val_speed_output_mae: 0.0662 - lr: 0.0010
# Epoch 9/100
# 345/345 [==============================] - 230s 667ms/step - loss: 0.0252 - angle_output_loss: 0.0093 - speed_output_loss: 0.0159 - angle_output_mae: 0.0715 - speed_output_mae: 0.0766 - val_loss: 0.0230 - val_angle_output_loss: 0.0083 - val_speed_output_loss: 0.0147 - val_angle_output_mae: 0.0659 - val_speed_output_mae: 0.0569 - lr: 0.0010
# Epoch 10/100
# 345/345 [==============================] - 230s 668ms/step - loss: 0.0212 - angle_output_loss: 0.0085 - speed_output_loss: 0.0127 - angle_output_mae: 0.0691 - speed_output_mae: 0.0694 - val_loss: 0.0177 - val_angle_output_loss: 0.0065 - val_speed_output_loss: 0.0112 - val_angle_output_mae: 0.0583 - val_speed_output_mae: 0.0508 - lr: 0.0010
# Epoch 11/100
# 345/345 [==============================] - 233s 676ms/step - loss: 0.0184 - angle_output_loss: 0.0079 - speed_output_loss: 0.0105 - angle_output_mae: 0.0669 - speed_output_mae: 0.0637 - val_loss: 0.0171 - val_angle_output_loss: 0.0068 - val_speed_output_loss: 0.0103 - val_angle_output_mae: 0.0581 - val_speed_output_mae: 0.0377 - lr: 9.0000e-04
# Epoch 00011: early stopping
# Finished training fold 2 with model EfficientNetB5
# Epoch 1/100
# 345/345 [==============================] - 404s 1s/step - loss: 0.1089 - angle_output_loss: 0.0404 - speed_output_loss: 0.0685 - angle_output_mae: 0.1412 - speed_output_mae: 0.1750 - val_loss: 0.0281 - val_angle_output_loss: 0.0104 - val_speed_output_loss: 0.0177 - val_angle_output_mae: 0.0755 - val_speed_output_mae: 0.0757 - lr: 0.0010
# Epoch 2/100
# 345/345 [==============================] - 376s 1s/step - loss: 0.0379 - angle_output_loss: 0.0152 - speed_output_loss: 0.0227 - angle_output_mae: 0.0942 - speed_output_mae: 0.0980 - val_loss: 0.0258 - val_angle_output_loss: 0.0110 - val_speed_output_loss: 0.0148 - val_angle_output_mae: 0.0810 - val_speed_output_mae: 0.0519 - lr: 0.0010
# Epoch 3/100
# 345/345 [==============================] - 376s 1s/step - loss: 0.0295 - angle_output_loss: 0.0123 - speed_output_loss: 0.0172 - angle_output_mae: 0.0848 - speed_output_mae: 0.0840 - val_loss: 0.0220 - val_angle_output_loss: 0.0091 - val_speed_output_loss: 0.0129 - val_angle_output_mae: 0.0713 - val_speed_output_mae: 0.0615 - lr: 0.0010
# Epoch 4/100
# 345/345 [==============================] - 377s 1s/step - loss: 0.0274 - angle_output_loss: 0.0111 - speed_output_loss: 0.0163 - angle_output_mae: 0.0812 - speed_output_mae: 0.0795 - val_loss: 0.0227 - val_angle_output_loss: 0.0079 - val_speed_output_loss: 0.0148 - val_angle_output_mae: 0.0648 - val_speed_output_mae: 0.0424 - lr: 0.0010
# Epoch 5/100
# 345/345 [==============================] - 376s 1s/step - loss: 0.0319 - angle_output_loss: 0.0109 - speed_output_loss: 0.0209 - angle_output_mae: 0.0792 - speed_output_mae: 0.0868 - val_loss: 0.0313 - val_angle_output_loss: 0.0110 - val_speed_output_loss: 0.0202 - val_angle_output_mae: 0.0769 - val_speed_output_mae: 0.0480 - lr: 0.0010
# Epoch 6/100
# 345/345 [==============================] - 377s 1s/step - loss: 0.0244 - angle_output_loss: 0.0097 - speed_output_loss: 0.0147 - angle_output_mae: 0.0748 - speed_output_mae: 0.0728 - val_loss: 0.0244 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0148 - val_angle_output_mae: 0.0720 - val_speed_output_mae: 0.0531 - lr: 0.0010
# Epoch 7/100
# 345/345 [==============================] - 377s 1s/step - loss: 0.0240 - angle_output_loss: 0.0091 - speed_output_loss: 0.0149 - angle_output_mae: 0.0724 - speed_output_mae: 0.0719 - val_loss: 0.0291 - val_angle_output_loss: 0.0097 - val_speed_output_loss: 0.0195 - val_angle_output_mae: 0.0743 - val_speed_output_mae: 0.0709 - lr: 0.0010
# Epoch 8/100
# 345/345 [==============================] - 379s 1s/step - loss: 0.0216 - angle_output_loss: 0.0092 - speed_output_loss: 0.0124 - angle_output_mae: 0.0719 - speed_output_mae: 0.0676 - val_loss: 0.0576 - val_angle_output_loss: 0.0087 - val_speed_output_loss: 0.0489 - val_angle_output_mae: 0.0662 - val_speed_output_mae: 0.1314 - lr: 0.0010
# Epoch 00008: early stopping
# Finished training fold 3 with model EfficientNetB7
# Epoch 1/100
# 345/345 [==============================] - 253s 685ms/step - loss: 0.0990 - angle_output_loss: 0.0344 - speed_output_loss: 0.0645 - angle_output_mae: 0.1361 - speed_output_mae: 0.1726 - val_loss: 0.0267 - val_angle_output_loss: 0.0107 - val_speed_output_loss: 0.0159 - val_angle_output_mae: 0.0746 - val_speed_output_mae: 0.0642 - lr: 0.0010
# Epoch 2/100
# 345/345 [==============================] - 233s 675ms/step - loss: 0.0395 - angle_output_loss: 0.0154 - speed_output_loss: 0.0241 - angle_output_mae: 0.0953 - speed_output_mae: 0.1024 - val_loss: 0.0263 - val_angle_output_loss: 0.0088 - val_speed_output_loss: 0.0175 - val_angle_output_mae: 0.0676 - val_speed_output_mae: 0.0854 - lr: 0.0010
# Epoch 3/100
# 345/345 [==============================] - 235s 681ms/step - loss: 0.0318 - angle_output_loss: 0.0124 - speed_output_loss: 0.0194 - angle_output_mae: 0.0852 - speed_output_mae: 0.0883 - val_loss: 0.0215 - val_angle_output_loss: 0.0077 - val_speed_output_loss: 0.0137 - val_angle_output_mae: 0.0629 - val_speed_output_mae: 0.0411 - lr: 0.0010
# Epoch 4/100
# 345/345 [==============================] - 233s 675ms/step - loss: 0.0268 - angle_output_loss: 0.0107 - speed_output_loss: 0.0160 - angle_output_mae: 0.0793 - speed_output_mae: 0.0802 - val_loss: 0.0287 - val_angle_output_loss: 0.0124 - val_speed_output_loss: 0.0163 - val_angle_output_mae: 0.0880 - val_speed_output_mae: 0.0632 - lr: 0.0010
# Epoch 5/100
# 345/345 [==============================] - 236s 684ms/step - loss: 0.0259 - angle_output_loss: 0.0099 - speed_output_loss: 0.0160 - angle_output_mae: 0.0757 - speed_output_mae: 0.0769 - val_loss: 0.0267 - val_angle_output_loss: 0.0121 - val_speed_output_loss: 0.0146 - val_angle_output_mae: 0.0832 - val_speed_output_mae: 0.0487 - lr: 0.0010
# Epoch 6/100
# 345/345 [==============================] - 235s 680ms/step - loss: 0.0233 - angle_output_loss: 0.0094 - speed_output_loss: 0.0138 - angle_output_mae: 0.0736 - speed_output_mae: 0.0736 - val_loss: 0.0220 - val_angle_output_loss: 0.0072 - val_speed_output_loss: 0.0148 - val_angle_output_mae: 0.0604 - val_speed_output_mae: 0.0605 - lr: 0.0010
# Epoch 7/100
# 345/345 [==============================] - 235s 681ms/step - loss: 0.0236 - angle_output_loss: 0.0089 - speed_output_loss: 0.0147 - angle_output_mae: 0.0711 - speed_output_mae: 0.0741 - val_loss: 0.0365 - val_angle_output_loss: 0.0101 - val_speed_output_loss: 0.0264 - val_angle_output_mae: 0.0730 - val_speed_output_mae: 0.0805 - lr: 0.0010
# Epoch 8/100
# 345/345 [==============================] - 235s 682ms/step - loss: 0.0229 - angle_output_loss: 0.0089 - speed_output_loss: 0.0140 - angle_output_mae: 0.0709 - speed_output_mae: 0.0715 - val_loss: 0.0203 - val_angle_output_loss: 0.0073 - val_speed_output_loss: 0.0130 - val_angle_output_mae: 0.0621 - val_speed_output_mae: 0.0419 - lr: 0.0010
# Epoch 9/100
# 345/345 [==============================] - 234s 678ms/step - loss: 0.0209 - angle_output_loss: 0.0083 - speed_output_loss: 0.0126 - angle_output_mae: 0.0694 - speed_output_mae: 0.0680 - val_loss: 0.0234 - val_angle_output_loss: 0.0072 - val_speed_output_loss: 0.0163 - val_angle_output_mae: 0.0607 - val_speed_output_mae: 0.0686 - lr: 0.0010
# Epoch 10/100
# 345/345 [==============================] - 234s 680ms/step - loss: 0.0222 - angle_output_loss: 0.0083 - speed_output_loss: 0.0138 - angle_output_mae: 0.0688 - speed_output_mae: 0.0704 - val_loss: 0.0225 - val_angle_output_loss: 0.0080 - val_speed_output_loss: 0.0145 - val_angle_output_mae: 0.0610 - val_speed_output_mae: 0.0487 - lr: 0.0010
# Epoch 11/100
# 345/345 [==============================] - 233s 675ms/step - loss: 0.0181 - angle_output_loss: 0.0076 - speed_output_loss: 0.0105 - angle_output_mae: 0.0662 - speed_output_mae: 0.0628 - val_loss: 0.0243 - val_angle_output_loss: 0.0076 - val_speed_output_loss: 0.0167 - val_angle_output_mae: 0.0610 - val_speed_output_mae: 0.0592 - lr: 9.0000e-04
# Epoch 12/100
# 345/345 [==============================] - 234s 677ms/step - loss: 0.0163 - angle_output_loss: 0.0074 - speed_output_loss: 0.0088 - angle_output_mae: 0.0648 - speed_output_mae: 0.0586 - val_loss: 0.0253 - val_angle_output_loss: 0.0083 - val_speed_output_loss: 0.0170 - val_angle_output_mae: 0.0636 - val_speed_output_mae: 0.0432 - lr: 8.1000e-04
# Epoch 13/100
# 345/345 [==============================] - 229s 662ms/step - loss: 0.0146 - angle_output_loss: 0.0069 - speed_output_loss: 0.0077 - angle_output_mae: 0.0629 - speed_output_mae: 0.0558 - val_loss: 0.0174 - val_angle_output_loss: 0.0064 - val_speed_output_loss: 0.0110 - val_angle_output_mae: 0.0577 - val_speed_output_mae: 0.0310 - lr: 7.2900e-04
# Epoch 14/100
# 345/345 [==============================] - 234s 679ms/step - loss: 0.0116 - angle_output_loss: 0.0059 - speed_output_loss: 0.0057 - angle_output_mae: 0.0590 - speed_output_mae: 0.0518 - val_loss: 0.0181 - val_angle_output_loss: 0.0071 - val_speed_output_loss: 0.0110 - val_angle_output_mae: 0.0598 - val_speed_output_mae: 0.0253 - lr: 6.5610e-04
# Epoch 15/100
# 345/345 [==============================] - 234s 679ms/step - loss: 0.0106 - angle_output_loss: 0.0056 - speed_output_loss: 0.0050 - angle_output_mae: 0.0574 - speed_output_mae: 0.0495 - val_loss: 0.0218 - val_angle_output_loss: 0.0064 - val_speed_output_loss: 0.0153 - val_angle_output_mae: 0.0574 - val_speed_output_mae: 0.0315 - lr: 5.9049e-04
# Epoch 16/100
# 345/345 [==============================] - 234s 680ms/step - loss: 0.0111 - angle_output_loss: 0.0055 - speed_output_loss: 0.0056 - angle_output_mae: 0.0569 - speed_output_mae: 0.0504 - val_loss: 0.0188 - val_angle_output_loss: 0.0069 - val_speed_output_loss: 0.0119 - val_angle_output_mae: 0.0594 - val_speed_output_mae: 0.0215 - lr: 5.3144e-04
# Epoch 17/100
# 345/345 [==============================] - 234s 678ms/step - loss: 0.0096 - angle_output_loss: 0.0049 - speed_output_loss: 0.0047 - angle_output_mae: 0.0543 - speed_output_mae: 0.0468 - val_loss: 0.0190 - val_angle_output_loss: 0.0063 - val_speed_output_loss: 0.0126 - val_angle_output_mae: 0.0565 - val_speed_output_mae: 0.0249 - lr: 4.7830e-04
# Epoch 18/100
# 345/345 [==============================] - 233s 677ms/step - loss: 0.0090 - angle_output_loss: 0.0047 - speed_output_loss: 0.0044 - angle_output_mae: 0.0532 - speed_output_mae: 0.0466 - val_loss: 0.0197 - val_angle_output_loss: 0.0069 - val_speed_output_loss: 0.0127 - val_angle_output_mae: 0.0595 - val_speed_output_mae: 0.0505 - lr: 4.3047e-04
# Epoch 00018: early stopping
# Finished training fold 3 with model EfficientNetB5
# Epoch 1/100
# 345/345 [==============================] - 412s 1s/step - loss: 0.1156 - angle_output_loss: 0.0468 - speed_output_loss: 0.0689 - angle_output_mae: 0.1445 - speed_output_mae: 0.1824 - val_loss: 0.0357 - val_angle_output_loss: 0.0150 - val_speed_output_loss: 0.0207 - val_angle_output_mae: 0.0929 - val_speed_output_mae: 0.0808 - lr: 0.0010
# Epoch 2/100
# 345/345 [==============================] - 374s 1s/step - loss: 0.0395 - angle_output_loss: 0.0160 - speed_output_loss: 0.0234 - angle_output_mae: 0.0973 - speed_output_mae: 0.1022 - val_loss: 0.0265 - val_angle_output_loss: 0.0099 - val_speed_output_loss: 0.0165 - val_angle_output_mae: 0.0765 - val_speed_output_mae: 0.0587 - lr: 0.0010
# Epoch 3/100
# 345/345 [==============================] - 380s 1s/step - loss: 0.0306 - angle_output_loss: 0.0125 - speed_output_loss: 0.0181 - angle_output_mae: 0.0859 - speed_output_mae: 0.0870 - val_loss: 0.0343 - val_angle_output_loss: 0.0102 - val_speed_output_loss: 0.0241 - val_angle_output_mae: 0.0769 - val_speed_output_mae: 0.0783 - lr: 0.0010
# Epoch 4/100
# 345/345 [==============================] - 380s 1s/step - loss: 0.0270 - angle_output_loss: 0.0110 - speed_output_loss: 0.0160 - angle_output_mae: 0.0803 - speed_output_mae: 0.0797 - val_loss: 0.0273 - val_angle_output_loss: 0.0103 - val_speed_output_loss: 0.0171 - val_angle_output_mae: 0.0753 - val_speed_output_mae: 0.0450 - lr: 0.0010
# Epoch 5/100
# 345/345 [==============================] - 379s 1s/step - loss: 0.0265 - angle_output_loss: 0.0106 - speed_output_loss: 0.0158 - angle_output_mae: 0.0774 - speed_output_mae: 0.0779 - val_loss: 0.0270 - val_angle_output_loss: 0.0073 - val_speed_output_loss: 0.0196 - val_angle_output_mae: 0.0634 - val_speed_output_mae: 0.0402 - lr: 0.0010
# Epoch 6/100
# 345/345 [==============================] - 378s 1s/step - loss: 0.0261 - angle_output_loss: 0.0099 - speed_output_loss: 0.0162 - angle_output_mae: 0.0751 - speed_output_mae: 0.0772 - val_loss: 0.0310 - val_angle_output_loss: 0.0079 - val_speed_output_loss: 0.0232 - val_angle_output_mae: 0.0658 - val_speed_output_mae: 0.0596 - lr: 0.0010
# Epoch 7/100
# 345/345 [==============================] - 379s 1s/step - loss: 0.0228 - angle_output_loss: 0.0091 - speed_output_loss: 0.0137 - angle_output_mae: 0.0720 - speed_output_mae: 0.0714 - val_loss: 0.0206 - val_angle_output_loss: 0.0069 - val_speed_output_loss: 0.0137 - val_angle_output_mae: 0.0613 - val_speed_output_mae: 0.0388 - lr: 0.0010
# Epoch 8/100
# 345/345 [==============================] - 380s 1s/step - loss: 0.0215 - angle_output_loss: 0.0086 - speed_output_loss: 0.0130 - angle_output_mae: 0.0697 - speed_output_mae: 0.0683 - val_loss: 0.0190 - val_angle_output_loss: 0.0066 - val_speed_output_loss: 0.0124 - val_angle_output_mae: 0.0597 - val_speed_output_mae: 0.0419 - lr: 0.0010
# Epoch 9/100
# 345/345 [==============================] - 375s 1s/step - loss: 0.0209 - angle_output_loss: 0.0084 - speed_output_loss: 0.0126 - angle_output_mae: 0.0691 - speed_output_mae: 0.0679 - val_loss: 0.0223 - val_angle_output_loss: 0.0079 - val_speed_output_loss: 0.0145 - val_angle_output_mae: 0.0641 - val_speed_output_mae: 0.0448 - lr: 0.0010
# Epoch 10/100
# 345/345 [==============================] - 376s 1s/step - loss: 0.0224 - angle_output_loss: 0.0090 - speed_output_loss: 0.0134 - angle_output_mae: 0.0708 - speed_output_mae: 0.0706 - val_loss: 0.0247 - val_angle_output_loss: 0.0085 - val_speed_output_loss: 0.0162 - val_angle_output_mae: 0.0682 - val_speed_output_mae: 0.0557 - lr: 0.0010
# Epoch 11/100
# 345/345 [==============================] - 378s 1s/step - loss: 0.0213 - angle_output_loss: 0.0082 - speed_output_loss: 0.0130 - angle_output_mae: 0.0682 - speed_output_mae: 0.0674 - val_loss: 0.0418 - val_angle_output_loss: 0.0126 - val_speed_output_loss: 0.0291 - val_angle_output_mae: 0.0888 - val_speed_output_mae: 0.0860 - lr: 9.0000e-04
# Epoch 12/100
# 345/345 [==============================] - 378s 1s/step - loss: 0.0195 - angle_output_loss: 0.0079 - speed_output_loss: 0.0116 - angle_output_mae: 0.0661 - speed_output_mae: 0.0640 - val_loss: 0.0285 - val_angle_output_loss: 0.0128 - val_speed_output_loss: 0.0158 - val_angle_output_mae: 0.0909 - val_speed_output_mae: 0.0320 - lr: 8.1000e-04
# Epoch 13/100
# 345/345 [==============================] - 379s 1s/step - loss: 0.0162 - angle_output_loss: 0.0070 - speed_output_loss: 0.0092 - angle_output_mae: 0.0634 - speed_output_mae: 0.0580 - val_loss: 0.0237 - val_angle_output_loss: 0.0069 - val_speed_output_loss: 0.0168 - val_angle_output_mae: 0.0611 - val_speed_output_mae: 0.0444 - lr: 7.2900e-04
# Epoch 00013: early stopping
# Finished training fold 4 with model EfficientNetB7
# Epoch 1/100
# 345/345 [==============================] - 253s 684ms/step - loss: 0.0987 - angle_output_loss: 0.0349 - speed_output_loss: 0.0638 - angle_output_mae: 0.1357 - speed_output_mae: 0.1772 - val_loss: 0.0323 - val_angle_output_loss: 0.0112 - val_speed_output_loss: 0.0212 - val_angle_output_mae: 0.0791 - val_speed_output_mae: 0.0596 - lr: 0.0010
# Epoch 2/100
# 345/345 [==============================] - 231s 668ms/step - loss: 0.0393 - angle_output_loss: 0.0152 - speed_output_loss: 0.0240 - angle_output_mae: 0.0951 - speed_output_mae: 0.1032 - val_loss: 0.0276 - val_angle_output_loss: 0.0087 - val_speed_output_loss: 0.0189 - val_angle_output_mae: 0.0724 - val_speed_output_mae: 0.0726 - lr: 0.0010
# Epoch 3/100
# 345/345 [==============================] - 232s 674ms/step - loss: 0.0313 - angle_output_loss: 0.0126 - speed_output_loss: 0.0187 - angle_output_mae: 0.0861 - speed_output_mae: 0.0891 - val_loss: 0.0298 - val_angle_output_loss: 0.0081 - val_speed_output_loss: 0.0217 - val_angle_output_mae: 0.0675 - val_speed_output_mae: 0.0612 - lr: 0.0010
# Epoch 4/100
# 345/345 [==============================] - 230s 666ms/step - loss: 0.0289 - angle_output_loss: 0.0111 - speed_output_loss: 0.0178 - angle_output_mae: 0.0807 - speed_output_mae: 0.0867 - val_loss: 0.0256 - val_angle_output_loss: 0.0073 - val_speed_output_loss: 0.0183 - val_angle_output_mae: 0.0631 - val_speed_output_mae: 0.0752 - lr: 0.0010
# Epoch 5/100
# 345/345 [==============================] - 229s 663ms/step - loss: 0.0250 - angle_output_loss: 0.0102 - speed_output_loss: 0.0148 - angle_output_mae: 0.0774 - speed_output_mae: 0.0783 - val_loss: 0.0269 - val_angle_output_loss: 0.0077 - val_speed_output_loss: 0.0192 - val_angle_output_mae: 0.0637 - val_speed_output_mae: 0.0575 - lr: 0.0010
# Epoch 6/100
# 345/345 [==============================] - 231s 669ms/step - loss: 0.0236 - angle_output_loss: 0.0098 - speed_output_loss: 0.0138 - angle_output_mae: 0.0745 - speed_output_mae: 0.0751 - val_loss: 0.0420 - val_angle_output_loss: 0.0095 - val_speed_output_loss: 0.0325 - val_angle_output_mae: 0.0717 - val_speed_output_mae: 0.0669 - lr: 0.0010
# Epoch 7/100
# 345/345 [==============================] - 232s 672ms/step - loss: 0.0274 - angle_output_loss: 0.0099 - speed_output_loss: 0.0175 - angle_output_mae: 0.0744 - speed_output_mae: 0.0816 - val_loss: 0.0231 - val_angle_output_loss: 0.0085 - val_speed_output_loss: 0.0147 - val_angle_output_mae: 0.0669 - val_speed_output_mae: 0.0441 - lr: 0.0010
# Epoch 8/100
# 345/345 [==============================] - 232s 673ms/step - loss: 0.0219 - angle_output_loss: 0.0092 - speed_output_loss: 0.0128 - angle_output_mae: 0.0715 - speed_output_mae: 0.0708 - val_loss: 0.0225 - val_angle_output_loss: 0.0073 - val_speed_output_loss: 0.0152 - val_angle_output_mae: 0.0620 - val_speed_output_mae: 0.0408 - lr: 0.0010
# Epoch 9/100
# 345/345 [==============================] - 230s 668ms/step - loss: 0.0220 - angle_output_loss: 0.0089 - speed_output_loss: 0.0131 - angle_output_mae: 0.0710 - speed_output_mae: 0.0711 - val_loss: 0.0263 - val_angle_output_loss: 0.0089 - val_speed_output_loss: 0.0174 - val_angle_output_mae: 0.0689 - val_speed_output_mae: 0.0561 - lr: 0.0010
# Epoch 10/100
# 345/345 [==============================] - 231s 671ms/step - loss: 0.0217 - angle_output_loss: 0.0086 - speed_output_loss: 0.0131 - angle_output_mae: 0.0694 - speed_output_mae: 0.0695 - val_loss: 0.0300 - val_angle_output_loss: 0.0081 - val_speed_output_loss: 0.0219 - val_angle_output_mae: 0.0653 - val_speed_output_mae: 0.0751 - lr: 0.0010
# Epoch 11/100
# 345/345 [==============================] - 232s 674ms/step - loss: 0.0204 - angle_output_loss: 0.0084 - speed_output_loss: 0.0120 - angle_output_mae: 0.0684 - speed_output_mae: 0.0676 - val_loss: 0.0221 - val_angle_output_loss: 0.0069 - val_speed_output_loss: 0.0152 - val_angle_output_mae: 0.0606 - val_speed_output_mae: 0.0398 - lr: 9.0000e-04
# Epoch 12/100
# 345/345 [==============================] - 232s 672ms/step - loss: 0.0171 - angle_output_loss: 0.0073 - speed_output_loss: 0.0098 - angle_output_mae: 0.0642 - speed_output_mae: 0.0615 - val_loss: 0.0248 - val_angle_output_loss: 0.0069 - val_speed_output_loss: 0.0179 - val_angle_output_mae: 0.0597 - val_speed_output_mae: 0.0364 - lr: 8.1000e-04
# Epoch 13/100
# 345/345 [==============================] - 231s 669ms/step - loss: 0.0156 - angle_output_loss: 0.0071 - speed_output_loss: 0.0085 - angle_output_mae: 0.0636 - speed_output_mae: 0.0586 - val_loss: 0.0214 - val_angle_output_loss: 0.0070 - val_speed_output_loss: 0.0145 - val_angle_output_mae: 0.0603 - val_speed_output_mae: 0.0389 - lr: 7.2900e-04
# Epoch 14/100
# 345/345 [==============================] - 233s 674ms/step - loss: 0.0127 - angle_output_loss: 0.0065 - speed_output_loss: 0.0062 - angle_output_mae: 0.0614 - speed_output_mae: 0.0527 - val_loss: 0.0206 - val_angle_output_loss: 0.0071 - val_speed_output_loss: 0.0135 - val_angle_output_mae: 0.0638 - val_speed_output_mae: 0.0329 - lr: 6.5610e-04
# Epoch 15/100
# 345/345 [==============================] - 233s 677ms/step - loss: 0.0125 - angle_output_loss: 0.0060 - speed_output_loss: 0.0065 - angle_output_mae: 0.0591 - speed_output_mae: 0.0531 - val_loss: 0.0229 - val_angle_output_loss: 0.0082 - val_speed_output_loss: 0.0147 - val_angle_output_mae: 0.0666 - val_speed_output_mae: 0.0404 - lr: 5.9049e-04
# Epoch 16/100
# 345/345 [==============================] - 234s 678ms/step - loss: 0.0110 - angle_output_loss: 0.0056 - speed_output_loss: 0.0054 - angle_output_mae: 0.0577 - speed_output_mae: 0.0507 - val_loss: 0.0192 - val_angle_output_loss: 0.0067 - val_speed_output_loss: 0.0125 - val_angle_output_mae: 0.0591 - val_speed_output_mae: 0.0261 - lr: 5.3144e-04
# Epoch 17/100
# 345/345 [==============================] - 235s 680ms/step - loss: 0.0094 - angle_output_loss: 0.0052 - speed_output_loss: 0.0042 - angle_output_mae: 0.0557 - speed_output_mae: 0.0476 - val_loss: 0.0201 - val_angle_output_loss: 0.0067 - val_speed_output_loss: 0.0134 - val_angle_output_mae: 0.0594 - val_speed_output_mae: 0.0258 - lr: 4.7830e-04
# Epoch 18/100
# 345/345 [==============================] - 234s 677ms/step - loss: 0.0087 - angle_output_loss: 0.0049 - speed_output_loss: 0.0038 - angle_output_mae: 0.0541 - speed_output_mae: 0.0462 - val_loss: 0.0195 - val_angle_output_loss: 0.0065 - val_speed_output_loss: 0.0130 - val_angle_output_mae: 0.0586 - val_speed_output_mae: 0.0289 - lr: 4.3047e-04
# Epoch 19/100
# 345/345 [==============================] - 233s 676ms/step - loss: 0.0082 - angle_output_loss: 0.0045 - speed_output_loss: 0.0037 - angle_output_mae: 0.0519 - speed_output_mae: 0.0451 - val_loss: 0.0201 - val_angle_output_loss: 0.0080 - val_speed_output_loss: 0.0121 - val_angle_output_mae: 0.0667 - val_speed_output_mae: 0.0261 - lr: 3.8742e-04
# Epoch 20/100
# 345/345 [==============================] - 233s 675ms/step - loss: 0.0087 - angle_output_loss: 0.0045 - speed_output_loss: 0.0042 - angle_output_mae: 0.0518 - speed_output_mae: 0.0459 - val_loss: 0.0239 - val_angle_output_loss: 0.0066 - val_speed_output_loss: 0.0174 - val_angle_output_mae: 0.0587 - val_speed_output_mae: 0.0355 - lr: 3.4868e-04
# Epoch 21/100
# 345/345 [==============================] - 232s 673ms/step - loss: 0.0077 - angle_output_loss: 0.0043 - speed_output_loss: 0.0034 - angle_output_mae: 0.0509 - speed_output_mae: 0.0436 - val_loss: 0.0192 - val_angle_output_loss: 0.0064 - val_speed_output_loss: 0.0128 - val_angle_output_mae: 0.0575 - val_speed_output_mae: 0.0214 - lr: 3.1381e-04
# Epoch 22/100
# 345/345 [==============================] - 232s 673ms/step - loss: 0.0067 - angle_output_loss: 0.0038 - speed_output_loss: 0.0030 - angle_output_mae: 0.0479 - speed_output_mae: 0.0419 - val_loss: 0.0203 - val_angle_output_loss: 0.0064 - val_speed_output_loss: 0.0139 - val_angle_output_mae: 0.0582 - val_speed_output_mae: 0.0219 - lr: 2.8243e-04
# Epoch 23/100
# 345/345 [==============================] - 232s 671ms/step - loss: 0.0060 - angle_output_loss: 0.0033 - speed_output_loss: 0.0027 - angle_output_mae: 0.0452 - speed_output_mae: 0.0414 - val_loss: 0.0202 - val_angle_output_loss: 0.0067 - val_speed_output_loss: 0.0136 - val_angle_output_mae: 0.0590 - val_speed_output_mae: 0.0223 - lr: 2.5419e-04
# Epoch 24/100
# 345/345 [==============================] - 232s 671ms/step - loss: 0.0056 - angle_output_loss: 0.0029 - speed_output_loss: 0.0026 - angle_output_mae: 0.0422 - speed_output_mae: 0.0402 - val_loss: 0.0189 - val_angle_output_loss: 0.0066 - val_speed_output_loss: 0.0122 - val_angle_output_mae: 0.0592 - val_speed_output_mae: 0.0247 - lr: 2.2877e-04
# Epoch 25/100
# 345/345 [==============================] - 232s 672ms/step - loss: 0.0052 - angle_output_loss: 0.0027 - speed_output_loss: 0.0025 - angle_output_mae: 0.0409 - speed_output_mae: 0.0396 - val_loss: 0.0193 - val_angle_output_loss: 0.0065 - val_speed_output_loss: 0.0128 - val_angle_output_mae: 0.0584 - val_speed_output_mae: 0.0233 - lr: 2.0589e-04
# Epoch 26/100
# 345/345 [==============================] - 232s 672ms/step - loss: 0.0048 - angle_output_loss: 0.0023 - speed_output_loss: 0.0025 - angle_output_mae: 0.0376 - speed_output_mae: 0.0393 - val_loss: 0.0204 - val_angle_output_loss: 0.0073 - val_speed_output_loss: 0.0131 - val_angle_output_mae: 0.0625 - val_speed_output_mae: 0.0247 - lr: 1.8530e-04
# Epoch 27/100
# 345/345 [==============================] - 230s 667ms/step - loss: 0.0045 - angle_output_loss: 0.0021 - speed_output_loss: 0.0024 - angle_output_mae: 0.0355 - speed_output_mae: 0.0391 - val_loss: 0.0189 - val_angle_output_loss: 0.0065 - val_speed_output_loss: 0.0124 - val_angle_output_mae: 0.0589 - val_speed_output_mae: 0.0262 - lr: 1.6677e-04
# Epoch 28/100
# 345/345 [==============================] - 233s 676ms/step - loss: 0.0043 - angle_output_loss: 0.0020 - speed_output_loss: 0.0024 - angle_output_mae: 0.0345 - speed_output_mae: 0.0385 - val_loss: 0.0201 - val_angle_output_loss: 0.0072 - val_speed_output_loss: 0.0130 - val_angle_output_mae: 0.0617 - val_speed_output_mae: 0.0261 - lr: 1.5009e-04
# Epoch 29/100
# 345/345 [==============================] - 233s 676ms/step - loss: 0.0041 - angle_output_loss: 0.0018 - speed_output_loss: 0.0023 - angle_output_mae: 0.0330 - speed_output_mae: 0.0376 - val_loss: 0.0202 - val_angle_output_loss: 0.0067 - val_speed_output_loss: 0.0135 - val_angle_output_mae: 0.0597 - val_speed_output_mae: 0.0221 - lr: 1.3509e-04
# Epoch 00029: early stopping
# Finished training fold 4 with model EfficientNetB5
# Epoch 1/100
# 345/345 [==============================] - 405s 1s/step - loss: 0.1091 - angle_output_loss: 0.0377 - speed_output_loss: 0.0714 - angle_output_mae: 0.1390 - speed_output_mae: 0.1825 - val_loss: 0.0351 - val_angle_output_loss: 0.0137 - val_speed_output_loss: 0.0214 - val_angle_output_mae: 0.0922 - val_speed_output_mae: 0.1081 - lr: 0.0010
# Epoch 2/100
# 345/345 [==============================] - 376s 1s/step - loss: 0.0375 - angle_output_loss: 0.0145 - speed_output_loss: 0.0230 - angle_output_mae: 0.0926 - speed_output_mae: 0.0999 - val_loss: 0.0203 - val_angle_output_loss: 0.0084 - val_speed_output_loss: 0.0119 - val_angle_output_mae: 0.0666 - val_speed_output_mae: 0.0507 - lr: 0.0010
# Epoch 3/100
# 345/345 [==============================] - 376s 1s/step - loss: 0.0325 - angle_output_loss: 0.0124 - speed_output_loss: 0.0201 - angle_output_mae: 0.0849 - speed_output_mae: 0.0912 - val_loss: 0.0207 - val_angle_output_loss: 0.0123 - val_speed_output_loss: 0.0083 - val_angle_output_mae: 0.0816 - val_speed_output_mae: 0.0430 - lr: 0.0010
# Epoch 4/100
# 345/345 [==============================] - 375s 1s/step - loss: 0.0268 - angle_output_loss: 0.0108 - speed_output_loss: 0.0159 - angle_output_mae: 0.0791 - speed_output_mae: 0.0801 - val_loss: 0.0205 - val_angle_output_loss: 0.0086 - val_speed_output_loss: 0.0119 - val_angle_output_mae: 0.0658 - val_speed_output_mae: 0.0378 - lr: 0.0010
# Epoch 5/100
# 345/345 [==============================] - 377s 1s/step - loss: 0.0265 - angle_output_loss: 0.0101 - speed_output_loss: 0.0164 - angle_output_mae: 0.0765 - speed_output_mae: 0.0800 - val_loss: 0.0238 - val_angle_output_loss: 0.0092 - val_speed_output_loss: 0.0146 - val_angle_output_mae: 0.0680 - val_speed_output_mae: 0.0610 - lr: 0.0010
# Epoch 6/100
# 345/345 [==============================] - 374s 1s/step - loss: 0.0274 - angle_output_loss: 0.0097 - speed_output_loss: 0.0177 - angle_output_mae: 0.0748 - speed_output_mae: 0.0794 - val_loss: 0.0210 - val_angle_output_loss: 0.0082 - val_speed_output_loss: 0.0127 - val_angle_output_mae: 0.0626 - val_speed_output_mae: 0.0473 - lr: 0.0010
# Epoch 7/100
# 345/345 [==============================] - 378s 1s/step - loss: 0.0259 - angle_output_loss: 0.0095 - speed_output_loss: 0.0165 - angle_output_mae: 0.0734 - speed_output_mae: 0.0759 - val_loss: 0.0283 - val_angle_output_loss: 0.0085 - val_speed_output_loss: 0.0199 - val_angle_output_mae: 0.0648 - val_speed_output_mae: 0.0487 - lr: 0.0010
# Epoch 00007: early stopping
# Finished training fold 5 with model EfficientNetB7
# Epoch 1/100
# 345/345 [==============================] - 255s 693ms/step - loss: 0.0945 - angle_output_loss: 0.0335 - speed_output_loss: 0.0610 - angle_output_mae: 0.1349 - speed_output_mae: 0.1731 - val_loss: 0.0264 - val_angle_output_loss: 0.0116 - val_speed_output_loss: 0.0147 - val_angle_output_mae: 0.0798 - val_speed_output_mae: 0.0686 - lr: 0.0010
# Epoch 2/100
# 345/345 [==============================] - 234s 678ms/step - loss: 0.0400 - angle_output_loss: 0.0154 - speed_output_loss: 0.0245 - angle_output_mae: 0.0950 - speed_output_mae: 0.1048 - val_loss: 0.0222 - val_angle_output_loss: 0.0109 - val_speed_output_loss: 0.0113 - val_angle_output_mae: 0.0799 - val_speed_output_mae: 0.0426 - lr: 0.0010
# Epoch 3/100
# 345/345 [==============================] - 235s 682ms/step - loss: 0.0318 - angle_output_loss: 0.0122 - speed_output_loss: 0.0196 - angle_output_mae: 0.0848 - speed_output_mae: 0.0904 - val_loss: 0.0191 - val_angle_output_loss: 0.0079 - val_speed_output_loss: 0.0111 - val_angle_output_mae: 0.0636 - val_speed_output_mae: 0.0385 - lr: 0.0010
# Epoch 4/100
# 345/345 [==============================] - 237s 687ms/step - loss: 0.0293 - angle_output_loss: 0.0111 - speed_output_loss: 0.0182 - angle_output_mae: 0.0805 - speed_output_mae: 0.0877 - val_loss: 0.0262 - val_angle_output_loss: 0.0098 - val_speed_output_loss: 0.0165 - val_angle_output_mae: 0.0748 - val_speed_output_mae: 0.0729 - lr: 0.0010
# Epoch 5/100
# 345/345 [==============================] - 234s 680ms/step - loss: 0.0283 - angle_output_loss: 0.0108 - speed_output_loss: 0.0175 - angle_output_mae: 0.0785 - speed_output_mae: 0.0833 - val_loss: 0.0218 - val_angle_output_loss: 0.0087 - val_speed_output_loss: 0.0130 - val_angle_output_mae: 0.0653 - val_speed_output_mae: 0.0334 - lr: 0.0010
# Epoch 6/100
# 345/345 [==============================] - 234s 679ms/step - loss: 0.0264 - angle_output_loss: 0.0099 - speed_output_loss: 0.0166 - angle_output_mae: 0.0751 - speed_output_mae: 0.0814 - val_loss: 0.0199 - val_angle_output_loss: 0.0075 - val_speed_output_loss: 0.0124 - val_angle_output_mae: 0.0621 - val_speed_output_mae: 0.0611 - lr: 0.0010
# Epoch 7/100
# 345/345 [==============================] - 235s 680ms/step - loss: 0.0225 - angle_output_loss: 0.0092 - speed_output_loss: 0.0133 - angle_output_mae: 0.0717 - speed_output_mae: 0.0730 - val_loss: 0.0278 - val_angle_output_loss: 0.0082 - val_speed_output_loss: 0.0195 - val_angle_output_mae: 0.0653 - val_speed_output_mae: 0.0606 - lr: 0.0010
# Epoch 8/100
# 345/345 [==============================] - 235s 681ms/step - loss: 0.0247 - angle_output_loss: 0.0089 - speed_output_loss: 0.0158 - angle_output_mae: 0.0712 - speed_output_mae: 0.0798 - val_loss: 0.0226 - val_angle_output_loss: 0.0096 - val_speed_output_loss: 0.0130 - val_angle_output_mae: 0.0704 - val_speed_output_mae: 0.0400 - lr: 0.0010
# Epoch 00008: early stopping
# Finished training fold 5 with model EfficientNetB5

# %%
# Calculate the value counts of the 'angle' column and sort them in descending order
angle_value_counts = submission_df['angle'].value_counts().sort_values(ascending=False)

# Print the sorted value counts
print(angle_value_counts)
# Out:
# 0.554257    1
# 0.152015    1
# 0.717110    1
# 0.182706    1
# 0.140189    1
#            ..
# 0.722515    1
# 0.574204    1
# 0.540897    1
# 0.675856    1
# 0.220762    1
# Name: angle, Length: 1020, dtype: int64

# %%
# Load train dataset
train_df = pd.read_csv('data/training_norm.csv')

# Calculate the value counts of the 'angle' column and sort them in descending order
angle_value_counts = train_df['angle'].value_counts().sort_values(ascending=False)

# Print the sorted value counts
print(angle_value_counts)
# Out:
# 0.7500    2123
# 0.5000    2046
# 0.6875    2007
# 0.6250    1963
# 0.5625    1609
# 0.4375    1467
# 0.8125    1147
# 0.3750     428
# 0.8750     301
# 0.3125     213
# 0.2500     104
# 0.1250      99
# 0.1875      98
# 0.9375      65
# 0.0000      60
# 1.0000      35
# 0.0625      28
# Name: angle, dtype: int64

# %%
unique_angles_train = np.unique(train_df['angle'])

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx]

submission_df['angle'] = submission_df['angle'].apply(lambda x: find_nearest(unique_angles_train, x))

submission_df.to_csv('submission_modified_ensemble.csv', index=False)

# %%
# Calculate the value counts of the 'angle' column and sort them in descending order
angle_value_counts = submission_df['angle'].value_counts().sort_values(ascending=False)

# Print the sorted value counts
print(angle_value_counts)
# Out:
# 0.6875    205
# 0.5000    193
# 0.7500    154
# 0.5625    128
# 0.6250     98
# 0.4375     59
# 0.1875     58
# 0.1250     27
# 0.2500     24
# 0.3750     18
# 0.8125     18
# 0.3125     14
# 0.0625     13
# 0.8750      6
# 0.9375      2
# 0.0000      2
# 1.0000      1
# Name: angle, dtype: int64
